# %% [markdown]
# # Problemas
#
# Como vimos acima, há muitos passos na criação e definição de uma nova rede neural.
# A grande parte desses ajustes dependem diretamente do problemas.
#
# Abaixo, listamos alguns problemas. Todos os problemas e datasets usados vem do [Center for Machine Learning and Intelligent Systems](http://archive.ics.uci.edu/ml/datasets.php).
#
#
# **Seu objetivo é determinar e implementar um modelo para cada problema.**
#
# Isso inclui:
#
# 1. definir uma arquitetura.
# Por enquanto usando somente camadas [Lineares](https://pytorch.org/docs/stable/nn.html#linear), porém podemos variar as ativações, como [Sigmoid](https://pytorch.org/docs/stable/nn.html#sigmoid), [Tanh](https://pytorch.org/docs/stable/nn.html#tanh), [ReLU](https://pytorch.org/docs/stable/nn.html#relu), [LeakyReLU](https://pytorch.org/docs/stable/generated/torch.nn.LeakyReLU.html), [ELU](https://pytorch.org/docs/stable/generated/torch.nn.ELU.html), [SeLU](https://pytorch.org/docs/stable/generated/torch.nn.SELU.html), [PReLU](https://pytorch.org/docs/stable/generated/torch.nn.PReLU.html), [RReLU](https://pytorch.org/docs/stable/generated/torch.nn.RReLU.html)
# 2. definir uma função de custo. Algums opções que vimos previamente incluem[L1](https://pytorch.org/docs/stable/nn.html#l1loss), [L2/MSE](https://pytorch.org/docs/stable/nn.html#mseloss), [Huber/SmoothL1](https://pytorch.org/docs/stable/nn.html#smoothl1loss), [*Cross-Entropy*](https://pytorch.org/docs/stable/nn.html#crossentropyloss), [Hinge](https://pytorch.org/docs/stable/nn.html#hingeembeddingloss)), e
# 3. definir um algoritmo de otimização ([SGD](https://pytorch.org/docs/stable/optim.html#torch.optim.SGD), [RMSProp](https://pytorch.org/docs/stable/optim.html#torch.optim.RMSprop), [Adam](https://pytorch.org/docs/stable/optim.html#torch.optim.Adam))
#
# A leitura do dado assim como a função de treinamento já estão implementados para você.

# %% [markdown]
# # Preâmbulo

# %%
# imports basicos
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

import torch
import torch.nn.functional as F
import torchvision

from torchvision import datasets, transforms
from torch import optim, nn

import os
import sys
import time
import numpy as np

# %%
import matplotlib.pyplot as plt
plt.ion()

# %%
# Test if GPU is avaliable, if not, use cpu instead
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
n = torch.cuda.device_count()
devices_ids = list(range(n))
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Funções básicas
#
# Use a função `load_array ` declarada a seguir se voce ja tem os dados armazenados em um **array** (por exemplo um array do numpy, o `np.array`). Pode acontecer de que os nossos dados vêm simplesmente de um dataset que pode ser armazennado em um array, e portanto não é necessário fazer os outros passos mais complicados como carregar os dados do disco, etc; basta que possamos recuperar esses dados em *batches* aleatórios. O resultado dessa função é um `DataLoader` do Pytorch com os dados que fornecemos de entrada, e que permite que os acessamos da seguinte forma:
#
# ```python
# data_loader = load_array(X, y, batch_size=32, is_train=True)
# for x_batch, y_batch in data_loader:
#     ### ... nossa iteração de treinamento aqui.
# ```
#
# Essa função recebe como parâmetro os seguintes valores:
#
# - `features`: um array que contém as features de todas as instâncias do dataset. Por exemplo, no caso do MNIST seria um array de tamanho `(60000, 28, 28, 1)` com todas as imagens do dataset de treino.
# - `labels`: um array que contém os rótulos de cada instância de dados. No caso do MNIST, seria um array de tamanho `(60000,)` em que a posição `i` contém o rótulo do dígito da posição `i` do array `features`.
# - `batch_size`: tamanho do batch desejado
# - `is_train`: um booleano que indica se o dataset que estamos criando é o conjunto de treinamento ou não (conjunto de teste). A única mudança que isso causa no `Dataloader` resultante é que se for o conjunto de treinamento ele cria batches aleatórios.

# %%
def load_array(features, labels, batch_size, is_train=True):
    """Construct a Torch data loader"""

    ## transform the input arrays in a tensor in case they are not
    if type(features) != torch.tensor:
        features = torch.tensor(features)
    if type(labels) != torch.tensor:
        labels = torch.tensor(labels)

    ## create a Pytorch Dataset and DataLoader with the input data
    dataset = torch.utils.data.TensorDataset(features, labels)
    return torch.utils.data.DataLoader(dataset, batch_size, shuffle=is_train)

# %% [markdown]
# Use a função `evaluate_accuracy` para calcular a acurácia e a *loss-function* para a rede em um conjunto de dados. Note que essa função pode ser usada tanto para avaliar a rede no conjunto de teste (no caso que usamos o `DataLoader` de teste) quanto o conjunto de treinamento (se usamos o `DataLoader` de treinamento). Os parâmetros são:
# - `data_iter`: um `DataLoader` que contém os dados que queremos usar para avaliar a rede. Repare que esse parâmetro tipicamente é o ojeto que obtemos como saída da função `load_array` para montar o nosso `DataLoader`.
# - `net`: a rede que queremos avaliar
# - `loss`: a nossa *loss-function*. Pode ser um objeto de qualquer uma das funções de perda que mencionamos acima no começo do notebook.
#
# O resultado dessa função é uma tupla em que o primeiro valor é a acurácia e o segundo a função de custo calculados.

# %%
# Função usada para calcular acurácia
def evaluate_accuracy(data_iter, net, loss):
    """Evaluate accuracy of a model on the given data set."""

    ## valores "acumuladores", que guardam a soma de, respectivamente, quantas instâncias
    ## prevemos corretamente, quantas instâncias percorremos no dataset, e o valor da loss; para
    ## todos os batches
    acc_sum, n, l = 0, 0, 0

    ## muda a rede para o "modo de teste". O que isso faz é mudar o comportamento de alguns módulos da rede,
    ## como os módulos de Dropout e BatchNorm, que funcionam de forma diferente quando estamos treinando ou
    ## quando estamos avaliando (ou usando em produção) a rede
    net.eval()

    with torch.no_grad():
      for X, y in data_iter:
          X, y = X.to(device), y.to(device)
          y_hat = net(X)
          l += loss(y_hat, y.long())

          ## aqui estamos calculando a quantidade de previsões que temos correta para o batch atual. o resultado
          ## do argmax é a posição de `y_hat` que possui o maior valor. Consequentemente isso resulta na classe que
          ## a rede deu o maior score.
          acc_sum += (y_hat.argmax(axis=1) == y).sum().item()

          ##
          n += y.size(0)

    return acc_sum / n, l.item() / len(data_iter)

# %% [markdown]
# A função `train_validate` é a função que implementa nossas iterações de treinamento padrão. Ela ja faz o trabalho de percorrer o dataset inteiro para cada época, e também de tempos em tempos avaliar a rede e mostar os resultados na tela. Para isso ela faz chamadas à função `evaluate_accuracy` declarada anteriormente (entre outras coisas). Essa função tem os segugintes parâmetros:
# - `net`: a rede que queremos treinar
# - `train_iter` e `test_iter`: nossos `DataLoaders` que criamos para acessar os dados. Esses DataLoaders podem ser criados com a função `load_array` declarada acima.
# - `trainer`: é o nosso otimizador. Podemos usar aqui qualquer um dos otimizadores que escolhermos da lista citada no começo desse notebook.
# - `loss`: a loss function que escolhemos para otimizar. Pode ser qualquer um das funções de custo citadas no começo do notebook.
# - `num_epochs`: a quantidade de épocas pelas quais queremos que o treinamento ocorra.
# - `type`: o tipo de tarefa que estamos lidando. Se for um problema de regressão, usamos `type='regression'`, e se for um problema de classificação, usamos `type='classification'`. Esse parâmetro é necessário para a função, por exemplo, saber quais métricas ele vai mostrar (acurácia, ou apenas o MSE, etc.)

# %%
# Função usada no treinamento e validação da rede
def train_validate(net, train_iter, test_iter, trainer, loss, num_epochs, type='regression'):
    print('training on', device)
    for epoch in range(num_epochs):
        train_l_sum, train_acc_sum, n, start = 0.0, 0.0, 0, time.time()
        for X, y in train_iter:
            X, y = X.to(device), y.to(device)
            trainer.zero_grad()
            y_hat = net(X)
            if type == 'regression':
              l = loss(y_hat, y.float())
            else:
              l = loss(y_hat, y.long())
            l.backward()
            trainer.step()
            train_l_sum += l.item()
            train_acc_sum += (y_hat.argmax(axis=1) == y).sum().item()
            n += y.size(0)
        test_acc, test_loss = evaluate_accuracy(test_iter, net, loss)
        if type == 'regression':
          print('epoch %d, train loss %.4f, test loss %.4f, time %.1f sec'
                % (epoch + 1, train_l_sum / len(train_iter), test_loss, time.time() - start))
        else:
          print('epoch %d, train loss %.4f, train acc %.3f, test loss %.4f, '
              'test acc %.3f, time %.1f sec'
              % (epoch + 1, train_l_sum / len(train_iter), train_acc_sum / n, test_loss,
                 test_acc, time.time() - start))

# %% [markdown]
# Use a função a seguir para inicializar os pesos da rede. Ela recebe como parâmetro um módulo da rede neural, e se for uma camada linear ele inicializa os pesos e os bias dessa camada. Embora possa parecer complicado de precisar chamar essa função para todas as camadas lineares da nossa rede, o módulos do Pytorch (que incluem tanto as redes criadas com o `nn.Sequential` ou com `nn.Module`) possuem a função `net.apply()` que recebe como parâmetro uma função e aplica ela a todos os submódulos da rede. Portanto, depois de ter criado a nossa rede, podemos chamar:
#
# ```python
# net.apply(weights_init)
# ```
# que automaticamente todas as camadas `nn.Linear` serão inicializadas. Caso queira saber mais sobre o `.apply()`, veja o seguinte [link](https://pytorch.org/docs/stable/generated/torch.nn.Module.html#torch.nn.Module.apply).

# %%
# Função para inicializar pesos da rede
def weights_init(m):
    if type(m) == nn.Linear:
        m.weight.data.normal_(0.0, 0.01) # valores iniciais são uma normal
        m.bias.data.fill_(0)

# %% [markdown]
# # Problema 1
#
# Neste problema, você receberá 14 *features* coletadas de pacientes e tentará predizer se eles tem algum sinal de doença cardíaca. Mais sobre esse dataset aqui: https://archive.ics.uci.edu/ml/datasets/Heart+Disease

# %%
## aqui fazemos o download do dataset usando o `!wget`. Se estamos rodando em um servidor linux (como é o caso do Colab),
## podemos usar comandos do linux precedidos pelo "!". Por exemplo podemos fazer !ls para listar os arquivos da instância do colab.
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data

## aqui fazemos um tratamento inicial dos dados. "np.genfromtxt" lê os dados de um arquivo .txt e transforma em
## um array. Pode ser interessante abrir o arquivo para verificar como os dados chegaram. Se estiver no colab, voce
## pode verificar o arquivo "processed.cleveland.data" clicando na pastinha do canto esquerdo da página. a função
## "np.nan_to_num" trata valores NaN e infinitos no dataset.
data = np.genfromtxt('processed.cleveland.data', delimiter=',', dtype=np.float32)
data = np.nan_to_num(data)
# Out:
# --2025-05-20 03:24:01--  https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘processed.cleveland.data’
#
# processed.cleveland     [ <=>                ]  18.03K  --.-KB/s    in 0.05s
#
# 2025-05-20 03:24:01 (372 KB/s) - ‘processed.cleveland.data’ saved [18461]

# %%
## aqui separamos os dados entre features (X) e rótulo (y), e depois separamos em um conjunto de treinamento e teste
print(data.shape, data[0, :])
X, y = data[:, :-1], data[:, -1]
print(X.shape, X[0, :])
print(y.shape, y[0])
train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.20, random_state=42)
# Out:
# (303, 14) [ 63.    1.    1.  145.  233.    1.    2.  150.    0.    2.3   3.    0.
#    6.    0. ]
# (303, 13) [ 63.    1.    1.  145.  233.    1.    2.  150.    0.    2.3   3.    0.
#    6. ]
# (303,) 0.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
## aqui criamos nossos DataLoaders para conseguirmos iterar nos dados
scaler = StandardScaler()
train_features = scaler.fit_transform(train_features)
test_features = scaler.transform(test_features)

batch_size = 64
train_iter = load_array(train_features, train_labels, batch_size)
test_iter = load_array(test_features, test_labels, batch_size, False)

# %%
# IMPLEMENTE AQUI


net = nn.Sequential(
    nn.Linear(13, 228),
    nn.ReLU(),
    nn.Linear(228, 228),
    nn.ReLU(),
    nn.Linear(228, 5)  # 5 classes
)

net.apply(weights_init)
net.to(device)

trainer = optim.Adam(net.parameters(), lr= 2.0, weight_decay= 0.0001)
loss = nn.CrossEntropyLoss()
num_epochs = 10000

train_validate(net, train_iter, test_iter, trainer, loss, num_epochs, type='classification')
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# epoch 5001, train loss 1.2580, train acc 0.558, test loss 1.4162, test acc 0.475, time 0.0 sec
# epoch 5002, train loss 1.2780, train acc 0.558, test loss 1.4349, test acc 0.475, time 0.0 sec
# epoch 5003, train loss 1.2930, train acc 0.558, test loss 100074.5391, test acc 0.246, time 0.0 sec
# epoch 5004, train loss 28085.6095, train acc 0.455, test loss 1.9473, test acc 0.475, time 0.0 sec
# epoch 5005, train loss 1.5712, train acc 0.558, test loss 1.3781, test acc 0.475, time 0.0 sec
# epoch 5006, train loss 319.8400, train acc 0.384, test loss 55850.9336, test acc 0.115, time 0.0 sec
# epoch 5007, train loss 26400.7693, train acc 0.360, test loss 3.4150, test acc 0.475, time 0.0 sec
# epoch 5008, train loss 20.1410, train acc 0.554, test loss 3.2475, test acc 0.475, time 0.0 sec
# epoch 5009, train loss 1124.4665, train acc 0.488, test loss 1.4515, test acc 0.475, time 0.0 sec
# epoch 5010, train loss 1.8477, train acc 0.264, test loss 1.7030, test acc 0.475, time 0.0 sec
# epoch 5011, train loss 1.6684, train acc 0.558, test loss 1.8393, test acc 0.475, time 0.0 sec
# epoch 5012, train loss 6360.0715, train acc 0.479, test loss 1.7292, test acc 0.475, time 0.0 sec
# epoch 5013, train loss 1.6693, train acc 0.558, test loss 1.7414, test acc 0.475, time 0.0 sec
# epoch 5014, train loss 16.3301, train acc 0.471, test loss 1.4659, test acc 0.475, time 0.0 sec
# epoch 5015, train loss 1.6862, train acc 0.554, test loss 1.7230, test acc 0.475, time 0.0 sec
# epoch 5016, train loss 1.3713, train acc 0.558, test loss 1.4552, test acc 0.475, time 0.0 sec
# epoch 5017, train loss 1.4014, train acc 0.426, test loss 1.5619, test acc 0.475, time 0.0 sec
# epoch 5018, train loss 1.3470, train acc 0.558, test loss 1.4861, test acc 0.475, time 0.0 sec
# epoch 5019, train loss 1.3242, train acc 0.450, test loss 1.4489, test acc 0.475, time 0.0 sec
# epoch 5020, train loss 43.9165, train acc 0.558, test loss 1.4130, test acc 0.475, time 0.0 sec
# epoch 5021, train loss 1.3023, train acc 0.558, test loss 2.3835, test acc 0.475, time 0.0 sec
# epoch 5022, train loss 1.3686, train acc 0.558, test loss 1.4476, test acc 0.475, time 0.0 sec
# epoch 5023, train loss 1.3040, train acc 0.558, test loss 1.5233, test acc 0.475, time 0.0 sec
# epoch 5024, train loss 1.3506, train acc 0.558, test loss 1.4162, test acc 0.475, time 0.0 sec
# epoch 5025, train loss 1.2633, train acc 0.558, test loss 1.4248, test acc 0.475, time 0.0 sec
# epoch 5026, train loss 1.2775, train acc 0.558, test loss 1.4610, test acc 0.475, time 0.0 sec
# epoch 5027, train loss 1.2818, train acc 0.558, test loss 1.3829, test acc 0.475, time 0.0 sec
# epoch 5028, train loss 1.2501, train acc 0.558, test loss 1.3951, test acc 0.475, time 0.0 sec
# epoch 5029, train loss 1.2265, train acc 0.558, test loss 1.4045, test acc 0.475, time 0.0 sec
# epoch 5030, train loss 1.2318, train acc 0.558, test loss 1.3759, test acc 0.475, time 0.0 sec
# epoch 5031, train loss 1.2211, train acc 0.558, test loss 1.3921, test acc 0.475, time 0.0 sec
# epoch 5032, train loss 1.2293, train acc 0.558, test loss 1.3936, test acc 0.475, time 0.0 sec
# epoch 5033, train loss 1.2425, train acc 0.558, test loss 1.3844, test acc 0.475, time 0.0 sec
# epoch 5034, train loss 1.2562, train acc 0.558, test loss 1.4272, test acc 0.475, time 0.0 sec
# epoch 5035, train loss 1.2680, train acc 0.554, test loss 1.3781, test acc 0.475, time 0.0 sec
# epoch 5036, train loss 1.2320, train acc 0.558, test loss 1.3942, test acc 0.475, time 0.0 sec
# epoch 5037, train loss 761.3625, train acc 0.533, test loss 1.4214, test acc 0.475, time 0.0 sec
# epoch 5038, train loss 6.7514, train acc 0.558, test loss 83482.3672, test acc 0.115, time 0.0 sec
# epoch 5039, train loss 24824.7305, train acc 0.430, test loss 2.0958, test acc 0.475, time 0.0 sec
# epoch 5040, train loss 1.9901, train acc 0.558, test loss 2.0430, test acc 0.475, time 0.0 sec
# epoch 5041, train loss 1.7218, train acc 0.558, test loss 2946.9258, test acc 0.475, time 0.0 sec
# epoch 5042, train loss 398.6967, train acc 0.467, test loss 1.6677, test acc 0.475, time 0.0 sec
# epoch 5043, train loss 1.3416, train acc 0.558, test loss 1.5206, test acc 0.492, time 0.0 sec
# epoch 5044, train loss 1736.9049, train acc 0.463, test loss 1.4161, test acc 0.475, time 0.0 sec
# epoch 5045, train loss 51.4753, train acc 0.554, test loss 1.6068, test acc 0.475, time 0.0 sec
# epoch 5046, train loss 2.7226, train acc 0.550, test loss 1.4758, test acc 0.475, time 0.0 sec
# epoch 5047, train loss 4.3269, train acc 0.558, test loss 1.4416, test acc 0.475, time 0.0 sec
# epoch 5048, train loss 53365.6813, train acc 0.285, test loss 2.1256, test acc 0.475, time 0.0 sec
# epoch 5049, train loss 486.9705, train acc 0.554, test loss 1.8433, test acc 0.475, time 0.0 sec
# epoch 5050, train loss 1.6461, train acc 0.368, test loss 1.7181, test acc 0.197, time 0.0 sec
# epoch 5051, train loss 1.5017, train acc 0.512, test loss 2.1053, test acc 0.475, time 0.0 sec
# epoch 5052, train loss 1.5418, train acc 0.463, test loss 1.5655, test acc 0.115, time 0.0 sec
# epoch 5053, train loss 1.4672, train acc 0.322, test loss 980.6304, test acc 0.475, time 0.0 sec
# epoch 5054, train loss 86.2599, train acc 0.554, test loss 1.3962, test acc 0.475, time 0.0 sec
# epoch 5055, train loss 1.2954, train acc 0.558, test loss 1.5137, test acc 0.475, time 0.0 sec
# epoch 5056, train loss 378.2292, train acc 0.554, test loss 1.3994, test acc 0.475, time 0.0 sec
# epoch 5057, train loss 1.2763, train acc 0.558, test loss 1.4326, test acc 0.475, time 0.0 sec
# epoch 5058, train loss 1.3567, train acc 0.558, test loss 1.3653, test acc 0.475, time 0.0 sec
# epoch 5059, train loss 1.2276, train acc 0.558, test loss 1.3376, test acc 0.475, time 0.0 sec
# epoch 5060, train loss 1.2372, train acc 0.558, test loss 1.3592, test acc 0.475, time 0.0 sec
# epoch 5061, train loss 1.2450, train acc 0.558, test loss 1.3533, test acc 0.475, time 0.0 sec
# epoch 5062, train loss 1.2390, train acc 0.558, test loss 1.3620, test acc 0.475, time 0.0 sec
# epoch 5063, train loss 1.2396, train acc 0.558, test loss 1.3991, test acc 0.475, time 0.0 sec
# epoch 5064, train loss 1.2615, train acc 0.558, test loss 1.3751, test acc 0.475, time 0.0 sec
# epoch 5065, train loss 4903.2632, train acc 0.558, test loss 1.3731, test acc 0.475, time 0.0 sec
# epoch 5066, train loss 1.2631, train acc 0.558, test loss 1.4634, test acc 0.475, time 0.0 sec
# epoch 5067, train loss 3757.2546, train acc 0.558, test loss 1.3730, test acc 0.475, time 0.0 sec
# epoch 5068, train loss 1.3524, train acc 0.463, test loss 1.4393, test acc 0.475, time 0.0 sec
# epoch 5069, train loss 1.2913, train acc 0.558, test loss 1.3842, test acc 0.475, time 0.0 sec
# epoch 5070, train loss 1.2909, train acc 0.558, test loss 1.3815, test acc 0.475, time 0.0 sec
# epoch 5071, train loss 1.3097, train acc 0.558, test loss 1.3974, test acc 0.475, time 0.0 sec
# epoch 5072, train loss 1.3688, train acc 0.558, test loss 1.4167, test acc 0.475, time 0.0 sec
# epoch 5073, train loss 1.3109, train acc 0.558, test loss 1.4129, test acc 0.475, time 0.0 sec
# epoch 5074, train loss 1.2763, train acc 0.558, test loss 1.3800, test acc 0.475, time 0.0 sec
# epoch 5075, train loss 1.2824, train acc 0.558, test loss 1.5156, test acc 0.475, time 0.0 sec
# epoch 5076, train loss 1.3047, train acc 0.558, test loss 1.3538, test acc 0.475, time 0.0 sec
# epoch 5077, train loss 1.2457, train acc 0.558, test loss 1.4387, test acc 0.475, time 0.0 sec
# epoch 5078, train loss 1.2747, train acc 0.558, test loss 1.3616, test acc 0.475, time 0.0 sec
# epoch 5079, train loss 1.2594, train acc 0.558, test loss 1.3916, test acc 0.475, time 0.0 sec
# epoch 5080, train loss 1.2728, train acc 0.558, test loss 1.3968, test acc 0.475, time 0.0 sec
# epoch 5081, train loss 1.2541, train acc 0.558, test loss 1.3735, test acc 0.475, time 0.0 sec
# epoch 5082, train loss 1.2524, train acc 0.558, test loss 1.4046, test acc 0.475, time 0.0 sec
# epoch 5083, train loss 1.2643, train acc 0.558, test loss 1.3805, test acc 0.475, time 0.0 sec
# epoch 5084, train loss 1.2702, train acc 0.558, test loss 1.3740, test acc 0.475, time 0.0 sec
# epoch 5085, train loss 1.2781, train acc 0.558, test loss 1.4103, test acc 0.475, time 0.0 sec
# epoch 5086, train loss 1.2775, train acc 0.558, test loss 1.4229, test acc 0.475, time 0.0 sec
# epoch 5087, train loss 1.2959, train acc 0.558, test loss 1.3947, test acc 0.475, time 0.0 sec
# epoch 5088, train loss 1.2933, train acc 0.558, test loss 1.4159, test acc 0.475, time 0.0 sec
# epoch 5089, train loss 1.3121, train acc 0.558, test loss 1.4052, test acc 0.475, time 0.0 sec
# epoch 5090, train loss 1.2895, train acc 0.558, test loss 1.3950, test acc 0.475, time 0.0 sec
# epoch 5091, train loss 1.2860, train acc 0.558, test loss 1.4229, test acc 0.475, time 0.0 sec
# epoch 5092, train loss 1.2787, train acc 0.558, test loss 1.4305, test acc 0.475, time 0.0 sec
# epoch 5093, train loss 1.2895, train acc 0.558, test loss 245.0119, test acc 0.328, time 0.0 sec
# epoch 5094, train loss 88.8723, train acc 0.496, test loss 1.4062, test acc 0.475, time 0.0 sec
# epoch 5095, train loss 1.3035, train acc 0.558, test loss 1.4588, test acc 0.475, time 0.0 sec
# epoch 5096, train loss 1.3248, train acc 0.558, test loss 1.4863, test acc 0.475, time 0.0 sec
# epoch 5097, train loss 1.2630, train acc 0.558, test loss 1.4206, test acc 0.475, time 0.0 sec
# epoch 5098, train loss 1.2703, train acc 0.558, test loss 116746.7656, test acc 0.393, time 0.0 sec
# epoch 5099, train loss 19517.8726, train acc 0.483, test loss 1.7506, test acc 0.475, time 0.0 sec
# epoch 5100, train loss 1.5507, train acc 0.558, test loss 1.5176, test acc 0.475, time 0.0 sec
# epoch 5101, train loss 1.2822, train acc 0.558, test loss 1.5934, test acc 0.475, time 0.0 sec
# epoch 5102, train loss 1.3457, train acc 0.558, test loss 1.5159, test acc 0.475, time 0.0 sec
# epoch 5103, train loss 1.3510, train acc 0.558, test loss 1.4183, test acc 0.475, time 0.0 sec
# epoch 5104, train loss 1.3182, train acc 0.558, test loss 1.4820, test acc 0.475, time 0.0 sec
# epoch 5105, train loss 1.2730, train acc 0.558, test loss 1.4286, test acc 0.475, time 0.0 sec
# epoch 5106, train loss 1.2738, train acc 0.558, test loss 1.4749, test acc 0.475, time 0.0 sec
# epoch 5107, train loss 1.3140, train acc 0.558, test loss 1.4250, test acc 0.475, time 0.0 sec
# epoch 5108, train loss 1.2661, train acc 0.558, test loss 1.5505, test acc 0.475, time 0.0 sec
# epoch 5109, train loss 1.3405, train acc 0.558, test loss 1.4212, test acc 0.475, time 0.0 sec
# epoch 5110, train loss 1.3296, train acc 0.558, test loss 1.4626, test acc 0.475, time 0.0 sec
# epoch 5111, train loss 1.3562, train acc 0.570, test loss 1.4528, test acc 0.475, time 0.0 sec
# epoch 5112, train loss 1.3480, train acc 0.558, test loss 1.5158, test acc 0.475, time 0.0 sec
# epoch 5113, train loss 1.3182, train acc 0.558, test loss 1.4454, test acc 0.475, time 0.0 sec
# epoch 5114, train loss 1.2855, train acc 0.558, test loss 1.4900, test acc 0.475, time 0.0 sec
# epoch 5115, train loss 1.3032, train acc 0.558, test loss 1.4383, test acc 0.475, time 0.0 sec
# epoch 5116, train loss 138.7301, train acc 0.554, test loss 1.4114, test acc 0.475, time 0.0 sec
# epoch 5117, train loss 1.2781, train acc 0.558, test loss 1.4493, test acc 0.475, time 0.0 sec
# epoch 5118, train loss 1.3037, train acc 0.558, test loss 1.4751, test acc 0.475, time 0.0 sec
# epoch 5119, train loss 1.2817, train acc 0.558, test loss 1.3935, test acc 0.475, time 0.0 sec
# epoch 5120, train loss 1.2972, train acc 0.558, test loss 1.4785, test acc 0.475, time 0.0 sec
# epoch 5121, train loss 1.3293, train acc 0.558, test loss 1.4182, test acc 0.475, time 0.0 sec
# epoch 5122, train loss 1.2659, train acc 0.558, test loss 1127.6505, test acc 0.180, time 0.0 sec
# epoch 5123, train loss 187.6242, train acc 0.413, test loss 2.3180, test acc 0.475, time 0.0 sec
# epoch 5124, train loss 2.0370, train acc 0.558, test loss 2.7593, test acc 0.475, time 0.0 sec
# epoch 5125, train loss 1.9997, train acc 0.558, test loss 2.8504, test acc 0.475, time 0.0 sec
# epoch 5126, train loss 2.0093, train acc 0.558, test loss 2.6538, test acc 0.475, time 0.0 sec
# epoch 5127, train loss 1.9360, train acc 0.558, test loss 2.5083, test acc 0.475, time 0.0 sec
# epoch 5128, train loss 1.7765, train acc 0.558, test loss 2.0515, test acc 0.475, time 0.0 sec
# epoch 5129, train loss 1.5746, train acc 0.558, test loss 1.6646, test acc 0.475, time 0.0 sec
# epoch 5130, train loss 1.3754, train acc 0.558, test loss 1.5078, test acc 0.475, time 0.0 sec
# epoch 5131, train loss 1.3685, train acc 0.558, test loss 1.4772, test acc 0.475, time 0.0 sec
# epoch 5132, train loss 1.3114, train acc 0.558, test loss 1.4968, test acc 0.475, time 0.0 sec
# epoch 5133, train loss 1.2967, train acc 0.558, test loss 1.4697, test acc 0.475, time 0.0 sec
# epoch 5134, train loss 1.2774, train acc 0.558, test loss 1.4200, test acc 0.475, time 0.0 sec
# epoch 5135, train loss 1.2929, train acc 0.558, test loss 1.4671, test acc 0.475, time 0.0 sec
# epoch 5136, train loss 1.2988, train acc 0.558, test loss 1.4441, test acc 0.475, time 0.0 sec
# epoch 5137, train loss 1.2646, train acc 0.558, test loss 1.4143, test acc 0.475, time 0.0 sec
# epoch 5138, train loss 1.2743, train acc 0.558, test loss 1.3901, test acc 0.475, time 0.0 sec
# epoch 5139, train loss 1.2875, train acc 0.558, test loss 1.4214, test acc 0.475, time 0.0 sec
# epoch 5140, train loss 1.2793, train acc 0.558, test loss 1.4247, test acc 0.475, time 0.0 sec
# epoch 5141, train loss 1.3143, train acc 0.558, test loss 1.4011, test acc 0.475, time 0.0 sec
# epoch 5142, train loss 1.3116, train acc 0.558, test loss 1.4215, test acc 0.475, time 0.0 sec
# epoch 5143, train loss 1.2981, train acc 0.558, test loss 1.4033, test acc 0.475, time 0.0 sec
# epoch 5144, train loss 1.2768, train acc 0.558, test loss 1.4218, test acc 0.475, time 0.0 sec
# epoch 5145, train loss 1.2653, train acc 0.558, test loss 1.4263, test acc 0.475, time 0.0 sec
# epoch 5146, train loss 1.2898, train acc 0.558, test loss 1.4046, test acc 0.475, time 0.0 sec
# epoch 5147, train loss 1.2647, train acc 0.558, test loss 1.4473, test acc 0.475, time 0.0 sec
# epoch 5148, train loss 1.2717, train acc 0.558, test loss 1.4085, test acc 0.475, time 0.0 sec
# epoch 5149, train loss 1.3209, train acc 0.558, test loss 1.4219, test acc 0.475, time 0.0 sec
# epoch 5150, train loss 1.2914, train acc 0.558, test loss 1.4554, test acc 0.475, time 0.0 sec
# epoch 5151, train loss 1.2942, train acc 0.558, test loss 1.4053, test acc 0.475, time 0.0 sec
# epoch 5152, train loss 1.2771, train acc 0.558, test loss 1.4395, test acc 0.475, time 0.0 sec
# epoch 5153, train loss 1.3040, train acc 0.558, test loss 2.9998, test acc 0.475, time 0.0 sec
# epoch 5154, train loss 1.2996, train acc 0.558, test loss 1.4448, test acc 0.475, time 0.0 sec
# epoch 5155, train loss 2.1815, train acc 0.558, test loss 1.3972, test acc 0.475, time 0.0 sec
# epoch 5156, train loss 1.3066, train acc 0.558, test loss 1.4552, test acc 0.475, time 0.0 sec
# epoch 5157, train loss 1.2824, train acc 0.558, test loss 1.3984, test acc 0.475, time 0.0 sec
# epoch 5158, train loss 1.2932, train acc 0.558, test loss 1.4485, test acc 0.475, time 0.0 sec
# epoch 5159, train loss 1.2733, train acc 0.558, test loss 1.3922, test acc 0.475, time 0.0 sec
# epoch 5160, train loss 1.2737, train acc 0.558, test loss 1.4338, test acc 0.475, time 0.0 sec
# epoch 5161, train loss 1.2746, train acc 0.558, test loss 1.3889, test acc 0.475, time 0.0 sec
# epoch 5162, train loss 1.2750, train acc 0.558, test loss 1.4444, test acc 0.475, time 0.0 sec
# epoch 5163, train loss 1.2880, train acc 0.558, test loss 1.4345, test acc 0.475, time 0.0 sec
# epoch 5164, train loss 1.2620, train acc 0.558, test loss 1.4263, test acc 0.475, time 0.0 sec
# epoch 5165, train loss 1.2937, train acc 0.558, test loss 1.4204, test acc 0.475, time 0.0 sec
# epoch 5166, train loss 1.3196, train acc 0.558, test loss 1.4260, test acc 0.475, time 0.0 sec
# epoch 5167, train loss 1.3399, train acc 0.558, test loss 1.5030, test acc 0.475, time 0.0 sec
# epoch 5168, train loss 1.2980, train acc 0.558, test loss 1.5006, test acc 0.475, time 0.0 sec
# epoch 5169, train loss 1.3853, train acc 0.558, test loss 1.3944, test acc 0.475, time 0.0 sec
# epoch 5170, train loss 1.3531, train acc 0.380, test loss 1.4579, test acc 0.475, time 0.0 sec
# epoch 5171, train loss 1.3341, train acc 0.558, test loss 1.4253, test acc 0.475, time 0.0 sec
# epoch 5172, train loss 1.3361, train acc 0.558, test loss 1.4454, test acc 0.475, time 0.0 sec
# epoch 5173, train loss 1.3151, train acc 0.558, test loss 1.4011, test acc 0.475, time 0.0 sec
# epoch 5174, train loss 1.2892, train acc 0.558, test loss 1.4243, test acc 0.475, time 0.0 sec
# epoch 5175, train loss 1.3444, train acc 0.558, test loss 1.3935, test acc 0.475, time 0.0 sec
# epoch 5176, train loss 1.3096, train acc 0.558, test loss 1.4236, test acc 0.475, time 0.0 sec
# epoch 5177, train loss 1.3123, train acc 0.558, test loss 1.4055, test acc 0.475, time 0.0 sec
# epoch 5178, train loss 1.2818, train acc 0.558, test loss 1.3997, test acc 0.475, time 0.0 sec
# epoch 5179, train loss 1.2646, train acc 0.558, test loss 1.4214, test acc 0.475, time 0.0 sec
# epoch 5180, train loss 1.2667, train acc 0.558, test loss 1.4050, test acc 0.475, time 0.0 sec
# epoch 5181, train loss 1.2942, train acc 0.558, test loss 1.4573, test acc 0.475, time 0.0 sec
# epoch 5182, train loss 1.2637, train acc 0.558, test loss 1.4217, test acc 0.475, time 0.0 sec
# epoch 5183, train loss 1.2809, train acc 0.558, test loss 1.4269, test acc 0.475, time 0.0 sec
# epoch 5184, train loss 1.2796, train acc 0.558, test loss 1.4074, test acc 0.475, time 0.0 sec
# epoch 5185, train loss 1.2727, train acc 0.558, test loss 1.4051, test acc 0.475, time 0.0 sec
# epoch 5186, train loss 1.2733, train acc 0.558, test loss 1.4248, test acc 0.475, time 0.0 sec
# epoch 5187, train loss 1.2850, train acc 0.558, test loss 1.4145, test acc 0.475, time 0.0 sec
# epoch 5188, train loss 1.2663, train acc 0.558, test loss 1.3928, test acc 0.475, time 0.0 sec
# epoch 5189, train loss 1.2772, train acc 0.558, test loss 1.4362, test acc 0.475, time 0.0 sec
# epoch 5190, train loss 1.2692, train acc 0.558, test loss 1.4133, test acc 0.475, time 0.0 sec
# epoch 5191, train loss 1.3003, train acc 0.558, test loss 1.4217, test acc 0.475, time 0.0 sec
# epoch 5192, train loss 1.2942, train acc 0.558, test loss 1.4307, test acc 0.475, time 0.0 sec
# epoch 5193, train loss 1.2775, train acc 0.558, test loss 1.4115, test acc 0.475, time 0.0 sec
# epoch 5194, train loss 1.2910, train acc 0.558, test loss 1.4113, test acc 0.475, time 0.0 sec
# epoch 5195, train loss 1.2916, train acc 0.558, test loss 1.4363, test acc 0.475, time 0.0 sec
# epoch 5196, train loss 1.3179, train acc 0.558, test loss 1.4174, test acc 0.475, time 0.0 sec
# epoch 5197, train loss 1.3351, train acc 0.558, test loss 1.4591, test acc 0.475, time 0.0 sec
# epoch 5198, train loss 1.2730, train acc 0.558, test loss 1.3933, test acc 0.475, time 0.0 sec
# epoch 5199, train loss 1.2726, train acc 0.558, test loss 1.4341, test acc 0.475, time 0.0 sec
# epoch 5200, train loss 1.2572, train acc 0.558, test loss 1.4107, test acc 0.475, time 0.0 sec
# epoch 5201, train loss 1.2633, train acc 0.558, test loss 1.4038, test acc 0.475, time 0.0 sec
# epoch 5202, train loss 1.2682, train acc 0.558, test loss 1.3897, test acc 0.475, time 0.0 sec
# epoch 5203, train loss 1.2558, train acc 0.558, test loss 1.4473, test acc 0.475, time 0.0 sec
# epoch 5204, train loss 1.2691, train acc 0.558, test loss 1.4012, test acc 0.475, time 0.0 sec
# epoch 5205, train loss 1.2876, train acc 0.558, test loss 1.4013, test acc 0.475, time 0.0 sec
# epoch 5206, train loss 1.2510, train acc 0.558, test loss 1.4297, test acc 0.475, time 0.0 sec
# epoch 5207, train loss 1.2830, train acc 0.558, test loss 1.4203, test acc 0.475, time 0.0 sec
# epoch 5208, train loss 157.2755, train acc 0.455, test loss 1.5856, test acc 0.475, time 0.0 sec
# epoch 5209, train loss 1.4409, train acc 0.558, test loss 2.0780, test acc 0.475, time 0.0 sec
# epoch 5210, train loss 1.6984, train acc 0.558, test loss 2.2422, test acc 0.475, time 0.0 sec
# epoch 5211, train loss 1.7239, train acc 0.558, test loss 2.1880, test acc 0.475, time 0.0 sec
# epoch 5212, train loss 1.6323, train acc 0.558, test loss 1.9414, test acc 0.475, time 0.0 sec
# epoch 5213, train loss 1.5113, train acc 0.558, test loss 1.6050, test acc 0.475, time 0.0 sec
# epoch 5214, train loss 1.3504, train acc 0.558, test loss 1.5265, test acc 0.475, time 0.0 sec
# epoch 5215, train loss 1.3645, train acc 0.558, test loss 1.5254, test acc 0.475, time 0.0 sec
# epoch 5216, train loss 1.3133, train acc 0.558, test loss 1.5606, test acc 0.475, time 0.0 sec
# epoch 5217, train loss 1.3332, train acc 0.558, test loss 1.5682, test acc 0.475, time 0.0 sec
# epoch 5218, train loss 1.3188, train acc 0.558, test loss 1.3967, test acc 0.475, time 0.0 sec
# epoch 5219, train loss 1.2955, train acc 0.558, test loss 1.4131, test acc 0.475, time 0.0 sec
# epoch 5220, train loss 1.3351, train acc 0.558, test loss 1.4305, test acc 0.475, time 0.0 sec
# epoch 5221, train loss 1.2906, train acc 0.558, test loss 1.4320, test acc 0.475, time 0.0 sec
# epoch 5222, train loss 1.2696, train acc 0.558, test loss 1.3724, test acc 0.475, time 0.0 sec
# epoch 5223, train loss 1204.8310, train acc 0.541, test loss 1.4035, test acc 0.475, time 0.0 sec
# epoch 5224, train loss 1.2895, train acc 0.558, test loss 1.4755, test acc 0.475, time 0.0 sec
# epoch 5225, train loss 1.2948, train acc 0.558, test loss 1.4099, test acc 0.475, time 0.0 sec
# epoch 5226, train loss 1.2689, train acc 0.558, test loss 1.4380, test acc 0.475, time 0.0 sec
# epoch 5227, train loss 1.2825, train acc 0.558, test loss 1.4103, test acc 0.475, time 0.0 sec
# epoch 5228, train loss 1.2692, train acc 0.558, test loss 1.4396, test acc 0.475, time 0.0 sec
# epoch 5229, train loss 1.2576, train acc 0.558, test loss 1.4086, test acc 0.475, time 0.0 sec
# epoch 5230, train loss 1.3082, train acc 0.558, test loss 1.3920, test acc 0.475, time 0.0 sec
# epoch 5231, train loss 7.8877, train acc 0.550, test loss 1.4352, test acc 0.475, time 0.0 sec
# epoch 5232, train loss 1.2954, train acc 0.558, test loss 1.4360, test acc 0.475, time 0.0 sec
# epoch 5233, train loss 1.3009, train acc 0.558, test loss 1.4290, test acc 0.475, time 0.0 sec
# epoch 5234, train loss 1.3050, train acc 0.558, test loss 1.4617, test acc 0.475, time 0.0 sec
# epoch 5235, train loss 1.3184, train acc 0.558, test loss 1.4198, test acc 0.475, time 0.0 sec
# epoch 5236, train loss 1.2715, train acc 0.558, test loss 1.4522, test acc 0.475, time 0.0 sec
# epoch 5237, train loss 1.2793, train acc 0.558, test loss 1.4353, test acc 0.475, time 0.0 sec
# epoch 5238, train loss 1.2891, train acc 0.558, test loss 1.4052, test acc 0.475, time 0.0 sec
# epoch 5239, train loss 1.3040, train acc 0.558, test loss 1.4628, test acc 0.475, time 0.0 sec
# epoch 5240, train loss 1.2771, train acc 0.558, test loss 1.3984, test acc 0.475, time 0.0 sec
# epoch 5241, train loss 1.2887, train acc 0.558, test loss 1.4783, test acc 0.475, time 0.0 sec
# epoch 5242, train loss 1.3008, train acc 0.558, test loss 1.3900, test acc 0.475, time 0.0 sec
# epoch 5243, train loss 1.2669, train acc 0.558, test loss 1.4249, test acc 0.475, time 0.0 sec
# epoch 5244, train loss 23.1856, train acc 0.558, test loss 1.4255, test acc 0.475, time 0.0 sec
# epoch 5245, train loss 1.3011, train acc 0.558, test loss 1.4265, test acc 0.475, time 0.0 sec
# epoch 5246, train loss 1.2906, train acc 0.558, test loss 1.4216, test acc 0.475, time 0.0 sec
# epoch 5247, train loss 1.2857, train acc 0.558, test loss 1.4161, test acc 0.475, time 0.0 sec
# epoch 5248, train loss 1.2674, train acc 0.558, test loss 1.4193, test acc 0.475, time 0.0 sec
# epoch 5249, train loss 1.2908, train acc 0.558, test loss 1.4030, test acc 0.475, time 0.0 sec
# epoch 5250, train loss 1.2828, train acc 0.558, test loss 1.4207, test acc 0.475, time 0.0 sec
# epoch 5251, train loss 1.2549, train acc 0.558, test loss 1.4394, test acc 0.475, time 0.0 sec
# epoch 5252, train loss 1.2691, train acc 0.558, test loss 1.3947, test acc 0.475, time 0.0 sec
# epoch 5253, train loss 1.2777, train acc 0.558, test loss 1.4336, test acc 0.475, time 0.0 sec
# epoch 5254, train loss 1.2767, train acc 0.558, test loss 1.3972, test acc 0.475, time 0.0 sec
# epoch 5255, train loss 29.7872, train acc 0.558, test loss 1.4577, test acc 0.475, time 0.0 sec
# epoch 5256, train loss 1.2702, train acc 0.558, test loss 1.4409, test acc 0.475, time 0.0 sec
# epoch 5257, train loss 1.2642, train acc 0.558, test loss 1.4149, test acc 0.475, time 0.0 sec
# epoch 5258, train loss 1.2823, train acc 0.558, test loss 1.4051, test acc 0.475, time 0.0 sec
# epoch 5259, train loss 1.3011, train acc 0.558, test loss 1.4318, test acc 0.475, time 0.0 sec
# epoch 5260, train loss 1.2784, train acc 0.558, test loss 1.3868, test acc 0.475, time 0.0 sec
# epoch 5261, train loss 1.2886, train acc 0.558, test loss 1.4587, test acc 0.475, time 0.0 sec
# epoch 5262, train loss 1.2762, train acc 0.558, test loss 1.4093, test acc 0.475, time 0.0 sec
# epoch 5263, train loss 1.2879, train acc 0.558, test loss 1.4067, test acc 0.475, time 0.0 sec
# epoch 5264, train loss 1.2889, train acc 0.558, test loss 1.4665, test acc 0.475, time 0.0 sec
# epoch 5265, train loss 2.2905, train acc 0.554, test loss 1.4158, test acc 0.475, time 0.0 sec
# epoch 5266, train loss 1.2648, train acc 0.558, test loss 1.4342, test acc 0.475, time 0.0 sec
# epoch 5267, train loss 2.0437, train acc 0.554, test loss 1.4270, test acc 0.475, time 0.0 sec
# epoch 5268, train loss 1.2862, train acc 0.558, test loss 1.4334, test acc 0.475, time 0.0 sec
# epoch 5269, train loss 1.2709, train acc 0.558, test loss 1.4585, test acc 0.475, time 0.0 sec
# epoch 5270, train loss 1.2741, train acc 0.558, test loss 1.3967, test acc 0.475, time 0.0 sec
# epoch 5271, train loss 1.2676, train acc 0.558, test loss 1.4762, test acc 0.475, time 0.0 sec
# epoch 5272, train loss 1.2888, train acc 0.558, test loss 1.3892, test acc 0.475, time 0.0 sec
# epoch 5273, train loss 1.2901, train acc 0.558, test loss 1.4943, test acc 0.475, time 0.0 sec
# epoch 5274, train loss 1.2922, train acc 0.558, test loss 1.4326, test acc 0.475, time 0.0 sec
# epoch 5275, train loss 1.3639, train acc 0.558, test loss 1.5483, test acc 0.475, time 0.0 sec
# epoch 5276, train loss 1.4002, train acc 0.558, test loss 1.4134, test acc 0.475, time 0.0 sec
# epoch 5277, train loss 1.3401, train acc 0.558, test loss 1.5346, test acc 0.475, time 0.0 sec
# epoch 5278, train loss 1.3119, train acc 0.558, test loss 1.4163, test acc 0.475, time 0.0 sec
# epoch 5279, train loss 1.3184, train acc 0.558, test loss 1.4600, test acc 0.475, time 0.0 sec
# epoch 5280, train loss 1.2950, train acc 0.558, test loss 1.4025, test acc 0.475, time 0.0 sec
# epoch 5281, train loss 1.2758, train acc 0.558, test loss 1.4846, test acc 0.475, time 0.0 sec
# epoch 5282, train loss 1.3408, train acc 0.558, test loss 1.4217, test acc 0.475, time 0.0 sec
# epoch 5283, train loss 1.2997, train acc 0.558, test loss 1.4433, test acc 0.475, time 0.0 sec
# epoch 5284, train loss 1.3145, train acc 0.558, test loss 1.4552, test acc 0.475, time 0.0 sec
# epoch 5285, train loss 1.3152, train acc 0.558, test loss 1.4322, test acc 0.475, time 0.0 sec
# epoch 5286, train loss 1.3438, train acc 0.558, test loss 1.4698, test acc 0.475, time 0.0 sec
# epoch 5287, train loss 1.2979, train acc 0.558, test loss 1.3929, test acc 0.475, time 0.0 sec
# epoch 5288, train loss 1.2727, train acc 0.558, test loss 1.4063, test acc 0.475, time 0.0 sec
# epoch 5289, train loss 1.2624, train acc 0.558, test loss 1.4323, test acc 0.475, time 0.0 sec
# epoch 5290, train loss 1.2850, train acc 0.558, test loss 1.4133, test acc 0.475, time 0.0 sec
# epoch 5291, train loss 1.2989, train acc 0.558, test loss 1.4347, test acc 0.475, time 0.0 sec
# epoch 5292, train loss 1.2801, train acc 0.558, test loss 1.4144, test acc 0.475, time 0.0 sec
# epoch 5293, train loss 1.2785, train acc 0.558, test loss 1.4184, test acc 0.475, time 0.0 sec
# epoch 5294, train loss 1.2805, train acc 0.558, test loss 1.4377, test acc 0.475, time 0.0 sec
# epoch 5295, train loss 1.2873, train acc 0.558, test loss 1.4142, test acc 0.475, time 0.0 sec
# epoch 5296, train loss 1.2759, train acc 0.558, test loss 1.4393, test acc 0.475, time 0.0 sec
# epoch 5297, train loss 1.2615, train acc 0.558, test loss 1.4000, test acc 0.475, time 0.0 sec
# epoch 5298, train loss 1.2674, train acc 0.558, test loss 1.4301, test acc 0.475, time 0.0 sec
# epoch 5299, train loss 1.2784, train acc 0.558, test loss 1.4059, test acc 0.475, time 0.0 sec
# epoch 5300, train loss 1.2691, train acc 0.558, test loss 1.4747, test acc 0.475, time 0.0 sec
# epoch 5301, train loss 1.2833, train acc 0.558, test loss 1.4206, test acc 0.475, time 0.0 sec
# epoch 5302, train loss 1.2928, train acc 0.558, test loss 1.4941, test acc 0.475, time 0.0 sec
# epoch 5303, train loss 1.3200, train acc 0.558, test loss 1.3957, test acc 0.475, time 0.0 sec
# epoch 5304, train loss 1.2923, train acc 0.558, test loss 1.4542, test acc 0.475, time 0.0 sec
# epoch 5305, train loss 1.2875, train acc 0.558, test loss 1.4319, test acc 0.475, time 0.0 sec
# epoch 5306, train loss 1.2680, train acc 0.558, test loss 1.4770, test acc 0.475, time 0.0 sec
# epoch 5307, train loss 1.2939, train acc 0.558, test loss 1.3906, test acc 0.475, time 0.0 sec
# epoch 5308, train loss 1.2480, train acc 0.558, test loss 1.4767, test acc 0.475, time 0.0 sec
# epoch 5309, train loss 1.3116, train acc 0.558, test loss 1.3944, test acc 0.475, time 0.0 sec
# epoch 5310, train loss 1.3109, train acc 0.558, test loss 1.4643, test acc 0.475, time 0.0 sec
# epoch 5311, train loss 1.2806, train acc 0.558, test loss 1.4081, test acc 0.475, time 0.0 sec
# epoch 5312, train loss 1.2895, train acc 0.558, test loss 1.3916, test acc 0.475, time 0.0 sec
# epoch 5313, train loss 1.2894, train acc 0.558, test loss 1.4563, test acc 0.475, time 0.0 sec
# epoch 5314, train loss 1.3112, train acc 0.558, test loss 1.4193, test acc 0.475, time 0.0 sec
# epoch 5315, train loss 1.2772, train acc 0.558, test loss 1.4397, test acc 0.475, time 0.0 sec
# epoch 5316, train loss 1.3022, train acc 0.558, test loss 1.4003, test acc 0.475, time 0.0 sec
# epoch 5317, train loss 1.2567, train acc 0.558, test loss 1.4521, test acc 0.475, time 0.0 sec
# epoch 5318, train loss 1.2961, train acc 0.558, test loss 1.4361, test acc 0.475, time 0.0 sec
# epoch 5319, train loss 1.3016, train acc 0.558, test loss 1.4068, test acc 0.475, time 0.0 sec
# epoch 5320, train loss 1.2647, train acc 0.554, test loss 1.4057, test acc 0.475, time 0.0 sec
# epoch 5321, train loss 1.2650, train acc 0.558, test loss 1.4116, test acc 0.475, time 0.0 sec
# epoch 5322, train loss 1.2844, train acc 0.558, test loss 1.4063, test acc 0.475, time 0.0 sec
# epoch 5323, train loss 1.2931, train acc 0.558, test loss 1.4817, test acc 0.475, time 0.0 sec
# epoch 5324, train loss 1.2889, train acc 0.558, test loss 1.3928, test acc 0.475, time 0.0 sec
# epoch 5325, train loss 1.2749, train acc 0.558, test loss 1.4621, test acc 0.475, time 0.0 sec
# epoch 5326, train loss 1.2786, train acc 0.558, test loss 1.4090, test acc 0.475, time 0.0 sec
# epoch 5327, train loss 1.3135, train acc 0.558, test loss 1.4550, test acc 0.475, time 0.0 sec
# epoch 5328, train loss 1.2902, train acc 0.558, test loss 1.4180, test acc 0.475, time 0.0 sec
# epoch 5329, train loss 1.3524, train acc 0.558, test loss 1.5067, test acc 0.475, time 0.0 sec
# epoch 5330, train loss 1.3290, train acc 0.558, test loss 1.4183, test acc 0.475, time 0.0 sec
# epoch 5331, train loss 1.2771, train acc 0.558, test loss 1.5370, test acc 0.475, time 0.0 sec
# epoch 5332, train loss 1.3120, train acc 0.558, test loss 1.3965, test acc 0.475, time 0.0 sec
# epoch 5333, train loss 1.3117, train acc 0.558, test loss 1.4472, test acc 0.475, time 0.0 sec
# epoch 5334, train loss 1.5142, train acc 0.558, test loss 1.4137, test acc 0.475, time 0.0 sec
# epoch 5335, train loss 17.9538, train acc 0.558, test loss 1.3944, test acc 0.475, time 0.0 sec
# epoch 5336, train loss 71.7574, train acc 0.463, test loss 1.4934, test acc 0.475, time 0.0 sec
# epoch 5337, train loss 1.3520, train acc 0.558, test loss 1.4344, test acc 0.475, time 0.0 sec
# epoch 5338, train loss 1.2579, train acc 0.558, test loss 1.4967, test acc 0.475, time 0.0 sec
# epoch 5339, train loss 1.3247, train acc 0.558, test loss 1.4446, test acc 0.475, time 0.0 sec
# epoch 5340, train loss 1.2789, train acc 0.558, test loss 1.3915, test acc 0.475, time 0.0 sec
# epoch 5341, train loss 1.2995, train acc 0.558, test loss 1.4341, test acc 0.475, time 0.0 sec
# epoch 5342, train loss 1.3093, train acc 0.558, test loss 1.4152, test acc 0.475, time 0.0 sec
# epoch 5343, train loss 1.2844, train acc 0.558, test loss 1.4995, test acc 0.475, time 0.0 sec
# epoch 5344, train loss 1.2882, train acc 0.558, test loss 1.4108, test acc 0.475, time 0.0 sec
# epoch 5345, train loss 1.2920, train acc 0.558, test loss 1.4604, test acc 0.475, time 0.0 sec
# epoch 5346, train loss 1.2900, train acc 0.558, test loss 1.4188, test acc 0.475, time 0.0 sec
# epoch 5347, train loss 1.2801, train acc 0.558, test loss 1.4146, test acc 0.475, time 0.0 sec
# epoch 5348, train loss 1.2655, train acc 0.558, test loss 1.4164, test acc 0.475, time 0.0 sec
# epoch 5349, train loss 1.2731, train acc 0.558, test loss 1.4202, test acc 0.475, time 0.0 sec
# epoch 5350, train loss 1.3311, train acc 0.558, test loss 1.4252, test acc 0.475, time 0.0 sec
# epoch 5351, train loss 1.2929, train acc 0.558, test loss 1.4107, test acc 0.475, time 0.0 sec
# epoch 5352, train loss 1.2678, train acc 0.558, test loss 1.4783, test acc 0.475, time 0.0 sec
# epoch 5353, train loss 1.2804, train acc 0.558, test loss 1.4003, test acc 0.475, time 0.0 sec
# epoch 5354, train loss 1.2879, train acc 0.558, test loss 1.4166, test acc 0.475, time 0.0 sec
# epoch 5355, train loss 1.2600, train acc 0.558, test loss 1.4138, test acc 0.475, time 0.0 sec
# epoch 5356, train loss 1.2585, train acc 0.558, test loss 1.4697, test acc 0.475, time 0.0 sec
# epoch 5357, train loss 1.2720, train acc 0.558, test loss 1.3900, test acc 0.475, time 0.0 sec
# epoch 5358, train loss 1.2634, train acc 0.558, test loss 1.4264, test acc 0.475, time 0.0 sec
# epoch 5359, train loss 1.2570, train acc 0.558, test loss 1.4037, test acc 0.475, time 0.0 sec
# epoch 5360, train loss 1.2961, train acc 0.558, test loss 1.4259, test acc 0.475, time 0.0 sec
# epoch 5361, train loss 1.2961, train acc 0.558, test loss 1.4270, test acc 0.475, time 0.0 sec
# epoch 5362, train loss 1.3173, train acc 0.558, test loss 1.4300, test acc 0.475, time 0.0 sec
# epoch 5363, train loss 1.2757, train acc 0.558, test loss 30684.3809, test acc 0.115, time 0.0 sec
# epoch 5364, train loss 8660.2718, train acc 0.455, test loss 2.4086, test acc 0.475, time 0.0 sec
# epoch 5365, train loss 2.2709, train acc 0.558, test loss 2.3232, test acc 0.475, time 0.0 sec
# epoch 5366, train loss 2.1017, train acc 0.558, test loss 1.7335, test acc 0.475, time 0.0 sec
# epoch 5367, train loss 1.5261, train acc 0.273, test loss 1.8608, test acc 0.115, time 0.0 sec
# epoch 5368, train loss 1.5326, train acc 0.450, test loss 1.5390, test acc 0.475, time 0.0 sec
# epoch 5369, train loss 20.0119, train acc 0.492, test loss 1.3944, test acc 0.475, time 0.0 sec
# epoch 5370, train loss 1.3320, train acc 0.558, test loss 1.4963, test acc 0.475, time 0.0 sec
# epoch 5371, train loss 1.3004, train acc 0.558, test loss 1.3733, test acc 0.475, time 0.0 sec
# epoch 5372, train loss 1773.3400, train acc 0.500, test loss 1.5630, test acc 0.475, time 0.0 sec
# epoch 5373, train loss 1.3743, train acc 0.558, test loss 1.4077, test acc 0.475, time 0.0 sec
# epoch 5374, train loss 1.2980, train acc 0.558, test loss 1.4936, test acc 0.475, time 0.0 sec
# epoch 5375, train loss 1.2891, train acc 0.558, test loss 1.4426, test acc 0.475, time 0.0 sec
# epoch 5376, train loss 1.2876, train acc 0.558, test loss 1.4016, test acc 0.475, time 0.0 sec
# epoch 5377, train loss 1.2736, train acc 0.558, test loss 1.4380, test acc 0.475, time 0.0 sec
# epoch 5378, train loss 1.2824, train acc 0.558, test loss 1.4441, test acc 0.475, time 0.0 sec
# epoch 5379, train loss 1.2725, train acc 0.558, test loss 1.4013, test acc 0.475, time 0.0 sec
# epoch 5380, train loss 1.2629, train acc 0.558, test loss 1.4158, test acc 0.475, time 0.0 sec
# epoch 5381, train loss 1.3069, train acc 0.562, test loss 1.4327, test acc 0.475, time 0.0 sec
# epoch 5382, train loss 1.2892, train acc 0.562, test loss 1.4252, test acc 0.475, time 0.0 sec
# epoch 5383, train loss 86.4332, train acc 0.541, test loss 1.5007, test acc 0.475, time 0.0 sec
# epoch 5384, train loss 1.3298, train acc 0.558, test loss 1.4254, test acc 0.475, time 0.0 sec
# epoch 5385, train loss 1.3367, train acc 0.562, test loss 1.4800, test acc 0.475, time 0.0 sec
# epoch 5386, train loss 1.2965, train acc 0.558, test loss 1.4153, test acc 0.475, time 0.0 sec
# epoch 5387, train loss 1.2747, train acc 0.562, test loss 1.4906, test acc 0.475, time 0.0 sec
# epoch 5388, train loss 1.2880, train acc 0.558, test loss 1.4178, test acc 0.475, time 0.0 sec
# epoch 5389, train loss 1.3020, train acc 0.558, test loss 1.4156, test acc 0.475, time 0.0 sec
# epoch 5390, train loss 1.3164, train acc 0.558, test loss 1.4519, test acc 0.475, time 0.0 sec
# epoch 5391, train loss 1.2974, train acc 0.562, test loss 1.4200, test acc 0.475, time 0.0 sec
# epoch 5392, train loss 651.4445, train acc 0.574, test loss 1.5049, test acc 0.475, time 0.0 sec
# epoch 5393, train loss 1.3416, train acc 0.558, test loss 1.3961, test acc 0.475, time 0.0 sec
# epoch 5394, train loss 2282.6427, train acc 0.310, test loss 1.4108, test acc 0.475, time 0.0 sec
# epoch 5395, train loss 1.3869, train acc 0.558, test loss 1.5682, test acc 0.475, time 0.0 sec
# epoch 5396, train loss 1.3839, train acc 0.434, test loss 1.3934, test acc 0.475, time 0.0 sec
# epoch 5397, train loss 1.3578, train acc 0.558, test loss 1.4711, test acc 0.475, time 0.0 sec
# epoch 5398, train loss 1.3296, train acc 0.426, test loss 1.4249, test acc 0.475, time 0.0 sec
# epoch 5399, train loss 1.3054, train acc 0.558, test loss 1.4035, test acc 0.475, time 0.0 sec
# epoch 5400, train loss 1.2952, train acc 0.558, test loss 1.4231, test acc 0.475, time 0.0 sec
# epoch 5401, train loss 1.2738, train acc 0.558, test loss 1.4639, test acc 0.475, time 0.0 sec
# epoch 5402, train loss 1.2708, train acc 0.558, test loss 1.4086, test acc 0.475, time 0.0 sec
# epoch 5403, train loss 1.2966, train acc 0.558, test loss 1.4086, test acc 0.475, time 0.0 sec
# epoch 5404, train loss 1.2545, train acc 0.558, test loss 1.4154, test acc 0.475, time 0.0 sec
# epoch 5405, train loss 1.3011, train acc 0.558, test loss 1.4450, test acc 0.475, time 0.0 sec
# epoch 5406, train loss 1.2779, train acc 0.558, test loss 1.4031, test acc 0.475, time 0.0 sec
# epoch 5407, train loss 1.2773, train acc 0.558, test loss 1.3921, test acc 0.475, time 0.0 sec
# epoch 5408, train loss 1.2819, train acc 0.558, test loss 1.4370, test acc 0.475, time 0.0 sec
# epoch 5409, train loss 1.3072, train acc 0.558, test loss 1.4715, test acc 0.475, time 0.0 sec
# epoch 5410, train loss 1.2880, train acc 0.558, test loss 1.3837, test acc 0.475, time 0.0 sec
# epoch 5411, train loss 1.3198, train acc 0.558, test loss 1.4549, test acc 0.475, time 0.0 sec
# epoch 5412, train loss 1.2630, train acc 0.558, test loss 1.4057, test acc 0.475, time 0.0 sec
# epoch 5413, train loss 1.2974, train acc 0.558, test loss 1.4460, test acc 0.475, time 0.0 sec
# epoch 5414, train loss 1.3171, train acc 0.558, test loss 1.4437, test acc 0.475, time 0.0 sec
# epoch 5415, train loss 1.2807, train acc 0.558, test loss 1.4299, test acc 0.475, time 0.0 sec
# epoch 5416, train loss 1.2824, train acc 0.558, test loss 1.3930, test acc 0.475, time 0.0 sec
# epoch 5417, train loss 1.3096, train acc 0.558, test loss 1.5266, test acc 0.475, time 0.0 sec
# epoch 5418, train loss 1.3444, train acc 0.558, test loss 1.4266, test acc 0.475, time 0.0 sec
# epoch 5419, train loss 1.2962, train acc 0.558, test loss 1.4332, test acc 0.475, time 0.0 sec
# epoch 5420, train loss 1.2937, train acc 0.558, test loss 1.4207, test acc 0.475, time 0.0 sec
# epoch 5421, train loss 1.3087, train acc 0.558, test loss 1.5337, test acc 0.475, time 0.0 sec
# epoch 5422, train loss 1.3146, train acc 0.558, test loss 1.4030, test acc 0.475, time 0.0 sec
# epoch 5423, train loss 1.2927, train acc 0.558, test loss 1.5007, test acc 0.475, time 0.0 sec
# epoch 5424, train loss 1.2864, train acc 0.558, test loss 1.4032, test acc 0.475, time 0.0 sec
# epoch 5425, train loss 1.2766, train acc 0.558, test loss 3.9581, test acc 0.475, time 0.0 sec
# epoch 5426, train loss 5.2548, train acc 0.558, test loss 1.3913, test acc 0.475, time 0.0 sec
# epoch 5427, train loss 1.2645, train acc 0.558, test loss 1.4250, test acc 0.475, time 0.0 sec
# epoch 5428, train loss 1.2790, train acc 0.558, test loss 1.4156, test acc 0.475, time 0.0 sec
# epoch 5429, train loss 1.2678, train acc 0.558, test loss 1.4088, test acc 0.475, time 0.0 sec
# epoch 5430, train loss 1.2737, train acc 0.558, test loss 1.4154, test acc 0.475, time 0.0 sec
# epoch 5431, train loss 1.3150, train acc 0.558, test loss 1.3897, test acc 0.475, time 0.0 sec
# epoch 5432, train loss 1.2855, train acc 0.558, test loss 1.4405, test acc 0.475, time 0.0 sec
# epoch 5433, train loss 1.2932, train acc 0.558, test loss 1.4160, test acc 0.475, time 0.0 sec
# epoch 5434, train loss 1.2934, train acc 0.558, test loss 1.4856, test acc 0.475, time 0.0 sec
# epoch 5435, train loss 1.3284, train acc 0.558, test loss 1.3949, test acc 0.475, time 0.0 sec
# epoch 5436, train loss 1.3905, train acc 0.558, test loss 1.4548, test acc 0.475, time 0.0 sec
# epoch 5437, train loss 1.3610, train acc 0.558, test loss 1.4399, test acc 0.475, time 0.0 sec
# epoch 5438, train loss 1.2939, train acc 0.558, test loss 1.4501, test acc 0.475, time 0.0 sec
# epoch 5439, train loss 1.2817, train acc 0.558, test loss 1.4610, test acc 0.475, time 0.0 sec
# epoch 5440, train loss 1.3135, train acc 0.558, test loss 1.4653, test acc 0.475, time 0.0 sec
# epoch 5441, train loss 1.3205, train acc 0.558, test loss 1.4231, test acc 0.475, time 0.0 sec
# epoch 5442, train loss 1.3118, train acc 0.558, test loss 1.4422, test acc 0.475, time 0.0 sec
# epoch 5443, train loss 1.2755, train acc 0.558, test loss 1.4665, test acc 0.475, time 0.0 sec
# epoch 5444, train loss 1.2882, train acc 0.558, test loss 1.4217, test acc 0.475, time 0.0 sec
# epoch 5445, train loss 1.2971, train acc 0.558, test loss 1.4187, test acc 0.475, time 0.0 sec
# epoch 5446, train loss 1.2606, train acc 0.558, test loss 1.4317, test acc 0.475, time 0.0 sec
# epoch 5447, train loss 1.2681, train acc 0.558, test loss 1.4428, test acc 0.475, time 0.0 sec
# epoch 5448, train loss 1.3052, train acc 0.558, test loss 1.4500, test acc 0.475, time 0.0 sec
# epoch 5449, train loss 1.3147, train acc 0.558, test loss 1.4176, test acc 0.475, time 0.0 sec
# epoch 5450, train loss 1.3754, train acc 0.397, test loss 1.5025, test acc 0.475, time 0.0 sec
# epoch 5451, train loss 1.3147, train acc 0.558, test loss 1.3978, test acc 0.475, time 0.0 sec
# epoch 5452, train loss 1.2835, train acc 0.558, test loss 1.5069, test acc 0.475, time 0.0 sec
# epoch 5453, train loss 1.2987, train acc 0.558, test loss 1.4051, test acc 0.475, time 0.0 sec
# epoch 5454, train loss 1.3876, train acc 0.554, test loss 1.4882, test acc 0.475, time 0.0 sec
# epoch 5455, train loss 1.2790, train acc 0.558, test loss 1.4121, test acc 0.475, time 0.0 sec
# epoch 5456, train loss 1.2892, train acc 0.558, test loss 1.4631, test acc 0.475, time 0.0 sec
# epoch 5457, train loss 1.3003, train acc 0.558, test loss 1.4005, test acc 0.475, time 0.0 sec
# epoch 5458, train loss 1.2914, train acc 0.558, test loss 1.4074, test acc 0.475, time 0.0 sec
# epoch 5459, train loss 1.2659, train acc 0.558, test loss 1.4223, test acc 0.475, time 0.0 sec
# epoch 5460, train loss 1.2714, train acc 0.558, test loss 1.4395, test acc 0.475, time 0.0 sec
# epoch 5461, train loss 1.2717, train acc 0.558, test loss 1.3905, test acc 0.475, time 0.0 sec
# epoch 5462, train loss 1.3230, train acc 0.558, test loss 1.4732, test acc 0.475, time 0.0 sec
# epoch 5463, train loss 1.2660, train acc 0.558, test loss 1.3847, test acc 0.475, time 0.0 sec
# epoch 5464, train loss 1.2713, train acc 0.558, test loss 1.4451, test acc 0.475, time 0.0 sec
# epoch 5465, train loss 1.2788, train acc 0.558, test loss 1.4195, test acc 0.475, time 0.0 sec
# epoch 5466, train loss 1.2654, train acc 0.558, test loss 1.4138, test acc 0.475, time 0.0 sec
# epoch 5467, train loss 1.2843, train acc 0.558, test loss 1.4673, test acc 0.475, time 0.0 sec
# epoch 5468, train loss 1.3112, train acc 0.558, test loss 1.3919, test acc 0.475, time 0.0 sec
# epoch 5469, train loss 1.3096, train acc 0.558, test loss 1.4715, test acc 0.475, time 0.0 sec
# epoch 5470, train loss 1.3268, train acc 0.558, test loss 1.4227, test acc 0.475, time 0.0 sec
# epoch 5471, train loss 1.3351, train acc 0.483, test loss 1.5539, test acc 0.475, time 0.0 sec
# epoch 5472, train loss 1.4071, train acc 0.558, test loss 1.4528, test acc 0.475, time 0.0 sec
# epoch 5473, train loss 1.3718, train acc 0.397, test loss 1.4925, test acc 0.475, time 0.0 sec
# epoch 5474, train loss 1.2980, train acc 0.558, test loss 1.3967, test acc 0.475, time 0.0 sec
# epoch 5475, train loss 1.2993, train acc 0.558, test loss 1.4348, test acc 0.475, time 0.0 sec
# epoch 5476, train loss 1.2922, train acc 0.558, test loss 1.4135, test acc 0.475, time 0.0 sec
# epoch 5477, train loss 1.2665, train acc 0.558, test loss 1.4289, test acc 0.475, time 0.0 sec
# epoch 5478, train loss 1.2874, train acc 0.558, test loss 1.4099, test acc 0.475, time 0.0 sec
# epoch 5479, train loss 1.2726, train acc 0.558, test loss 1.4394, test acc 0.475, time 0.0 sec
# epoch 5480, train loss 1.2766, train acc 0.558, test loss 1.3936, test acc 0.475, time 0.0 sec
# epoch 5481, train loss 1.3184, train acc 0.558, test loss 1.4893, test acc 0.475, time 0.0 sec
# epoch 5482, train loss 1.2859, train acc 0.558, test loss 1.4163, test acc 0.475, time 0.0 sec
# epoch 5483, train loss 1.2745, train acc 0.558, test loss 1.4071, test acc 0.475, time 0.0 sec
# epoch 5484, train loss 1.2712, train acc 0.558, test loss 1.4279, test acc 0.475, time 0.0 sec
# epoch 5485, train loss 1.2560, train acc 0.558, test loss 1.4219, test acc 0.475, time 0.0 sec
# epoch 5486, train loss 1.2989, train acc 0.558, test loss 1.4505, test acc 0.475, time 0.0 sec
# epoch 5487, train loss 1.2852, train acc 0.558, test loss 1.4009, test acc 0.475, time 0.0 sec
# epoch 5488, train loss 1.2994, train acc 0.558, test loss 1.5005, test acc 0.475, time 0.0 sec
# epoch 5489, train loss 1.3061, train acc 0.558, test loss 1.4111, test acc 0.475, time 0.0 sec
# epoch 5490, train loss 1.2995, train acc 0.558, test loss 1.4600, test acc 0.475, time 0.0 sec
# epoch 5491, train loss 1.3100, train acc 0.558, test loss 1.4595, test acc 0.475, time 0.0 sec
# epoch 5492, train loss 1.2783, train acc 0.558, test loss 1.4189, test acc 0.475, time 0.0 sec
# epoch 5493, train loss 1.2746, train acc 0.558, test loss 1.3952, test acc 0.475, time 0.0 sec
# epoch 5494, train loss 1.2577, train acc 0.558, test loss 1.4562, test acc 0.475, time 0.0 sec
# epoch 5495, train loss 1.2688, train acc 0.558, test loss 1.4063, test acc 0.475, time 0.0 sec
# epoch 5496, train loss 1.2724, train acc 0.558, test loss 1.4056, test acc 0.475, time 0.0 sec
# epoch 5497, train loss 1.2841, train acc 0.558, test loss 6145.6240, test acc 0.148, time 0.0 sec
# epoch 5498, train loss 1203.7085, train acc 0.442, test loss 2.4587, test acc 0.475, time 0.0 sec
# epoch 5499, train loss 2.0752, train acc 0.558, test loss 2.3826, test acc 0.475, time 0.0 sec
# epoch 5500, train loss 1.7842, train acc 0.558, test loss 1.5710, test acc 0.475, time 0.0 sec
# epoch 5501, train loss 1.4793, train acc 0.351, test loss 1.5210, test acc 0.475, time 0.0 sec
# epoch 5502, train loss 1.5247, train acc 0.558, test loss 1.7192, test acc 0.475, time 0.0 sec
# epoch 5503, train loss 1.4867, train acc 0.471, test loss 1.4939, test acc 0.475, time 0.0 sec
# ...
# epoch 9833, train loss 1.3245, train acc 0.558, test loss 1.4752, test acc 0.475, time 0.0 sec
# epoch 9834, train loss 1.3799, train acc 0.558, test loss 1.4456, test acc 0.475, time 0.0 sec
# epoch 9835, train loss 1.3702, train acc 0.434, test loss 1.5258, test acc 0.475, time 0.0 sec
# epoch 9836, train loss 1.3351, train acc 0.558, test loss 1.4196, test acc 0.475, time 0.0 sec
# epoch 9837, train loss 1.2930, train acc 0.558, test loss 1.4674, test acc 0.475, time 0.0 sec
# epoch 9838, train loss 1.3051, train acc 0.558, test loss 1.4043, test acc 0.475, time 0.0 sec
# epoch 9839, train loss 1.3110, train acc 0.558, test loss 1.5087, test acc 0.475, time 0.0 sec
# epoch 9840, train loss 1.2861, train acc 0.558, test loss 1.4396, test acc 0.475, time 0.0 sec
# epoch 9841, train loss 1.2819, train acc 0.558, test loss 1.4273, test acc 0.475, time 0.0 sec
# epoch 9842, train loss 1.2877, train acc 0.558, test loss 1.4200, test acc 0.475, time 0.0 sec
# epoch 9843, train loss 123.5177, train acc 0.533, test loss 1.5384, test acc 0.475, time 0.0 sec
# epoch 9844, train loss 1.3001, train acc 0.558, test loss 1.4223, test acc 0.475, time 0.0 sec
# epoch 9845, train loss 1.2898, train acc 0.558, test loss 1.4255, test acc 0.475, time 0.0 sec
# epoch 9846, train loss 1.2852, train acc 0.558, test loss 1.4465, test acc 0.475, time 0.0 sec
# epoch 9847, train loss 1.2952, train acc 0.558, test loss 1.4175, test acc 0.475, time 0.0 sec
# epoch 9848, train loss 1.2892, train acc 0.558, test loss 1.4040, test acc 0.475, time 0.0 sec
# epoch 9849, train loss 1.2856, train acc 0.558, test loss 1.4151, test acc 0.475, time 0.0 sec
# epoch 9850, train loss 1.2719, train acc 0.558, test loss 1.3987, test acc 0.475, time 0.0 sec
# epoch 9851, train loss 1.2923, train acc 0.558, test loss 1.4701, test acc 0.475, time 0.0 sec
# epoch 9852, train loss 1.2863, train acc 0.558, test loss 1.4248, test acc 0.475, time 0.0 sec
# epoch 9853, train loss 1.7582, train acc 0.558, test loss 1.3854, test acc 0.475, time 0.0 sec
# epoch 9854, train loss 1.3001, train acc 0.558, test loss 1.4594, test acc 0.475, time 0.0 sec
# epoch 9855, train loss 1.3515, train acc 0.558, test loss 1.4166, test acc 0.475, time 0.0 sec
# epoch 9856, train loss 1.3587, train acc 0.558, test loss 1.4963, test acc 0.475, time 0.0 sec
# epoch 9857, train loss 1.3413, train acc 0.558, test loss 1.4396, test acc 0.475, time 0.0 sec
# epoch 9858, train loss 1.3360, train acc 0.450, test loss 1.5197, test acc 0.475, time 0.0 sec
# epoch 9859, train loss 1.4123, train acc 0.558, test loss 1.4232, test acc 0.475, time 0.0 sec
# epoch 9860, train loss 1.3028, train acc 0.558, test loss 1.4884, test acc 0.475, time 0.0 sec
# epoch 9861, train loss 1.2742, train acc 0.558, test loss 1.4594, test acc 0.475, time 0.0 sec
# epoch 9862, train loss 1.3209, train acc 0.558, test loss 1.4046, test acc 0.475, time 0.0 sec
# epoch 9863, train loss 1.2682, train acc 0.558, test loss 1.4778, test acc 0.475, time 0.0 sec
# epoch 9864, train loss 1.3438, train acc 0.558, test loss 1.4289, test acc 0.475, time 0.0 sec
# epoch 9865, train loss 1.3239, train acc 0.558, test loss 1.5164, test acc 0.475, time 0.0 sec
# epoch 9866, train loss 1.3121, train acc 0.558, test loss 1.4168, test acc 0.475, time 0.0 sec
# epoch 9867, train loss 1.3152, train acc 0.558, test loss 1.4730, test acc 0.475, time 0.0 sec
# epoch 9868, train loss 1.2975, train acc 0.558, test loss 1.4170, test acc 0.475, time 0.0 sec
# epoch 9869, train loss 1.2943, train acc 0.558, test loss 1.4359, test acc 0.475, time 0.0 sec
# epoch 9870, train loss 1.2826, train acc 0.558, test loss 1.4659, test acc 0.475, time 0.0 sec
# epoch 9871, train loss 1.3303, train acc 0.558, test loss 1.4444, test acc 0.475, time 0.0 sec
# epoch 9872, train loss 1.2970, train acc 0.558, test loss 1.4316, test acc 0.475, time 0.0 sec
# epoch 9873, train loss 1.2809, train acc 0.558, test loss 1.4878, test acc 0.475, time 0.0 sec
# epoch 9874, train loss 1.3052, train acc 0.558, test loss 1.4082, test acc 0.475, time 0.0 sec
# epoch 9875, train loss 1.2668, train acc 0.558, test loss 1.4175, test acc 0.475, time 0.0 sec
# epoch 9876, train loss 1.2748, train acc 0.558, test loss 1.4470, test acc 0.475, time 0.0 sec
# epoch 9877, train loss 1.2756, train acc 0.558, test loss 1.3975, test acc 0.475, time 0.0 sec
# epoch 9878, train loss 1.2897, train acc 0.558, test loss 1.4144, test acc 0.475, time 0.0 sec
# epoch 9879, train loss 1.2821, train acc 0.558, test loss 1.4299, test acc 0.475, time 0.0 sec
# epoch 9880, train loss 1.3198, train acc 0.558, test loss 1.4980, test acc 0.475, time 0.0 sec
# epoch 9881, train loss 1.3234, train acc 0.558, test loss 1.4063, test acc 0.475, time 0.0 sec
# epoch 9882, train loss 1.3264, train acc 0.558, test loss 1.4974, test acc 0.475, time 0.0 sec
# epoch 9883, train loss 1.2809, train acc 0.558, test loss 1.4070, test acc 0.475, time 0.0 sec
# epoch 9884, train loss 1.2544, train acc 0.558, test loss 1.4993, test acc 0.475, time 0.0 sec
# epoch 9885, train loss 1.3576, train acc 0.558, test loss 1.4464, test acc 0.475, time 0.0 sec
# epoch 9886, train loss 1.3654, train acc 0.558, test loss 1.5089, test acc 0.475, time 0.0 sec
# epoch 9887, train loss 1.3094, train acc 0.558, test loss 1.4483, test acc 0.475, time 0.0 sec
# epoch 9888, train loss 1.3171, train acc 0.558, test loss 1.4775, test acc 0.475, time 0.0 sec
# epoch 9889, train loss 1.2786, train acc 0.558, test loss 1.4127, test acc 0.475, time 0.0 sec
# epoch 9890, train loss 1.2705, train acc 0.558, test loss 1.4988, test acc 0.475, time 0.0 sec
# epoch 9891, train loss 1.3495, train acc 0.558, test loss 1.5037, test acc 0.475, time 0.0 sec
# epoch 9892, train loss 1.3454, train acc 0.471, test loss 1.5396, test acc 0.475, time 0.0 sec
# epoch 9893, train loss 1.3522, train acc 0.558, test loss 1.3874, test acc 0.475, time 0.0 sec
# epoch 9894, train loss 1.2840, train acc 0.558, test loss 1.4890, test acc 0.475, time 0.0 sec
# epoch 9895, train loss 1.2817, train acc 0.558, test loss 1.4091, test acc 0.475, time 0.0 sec
# epoch 9896, train loss 1.3023, train acc 0.558, test loss 1.4659, test acc 0.475, time 0.0 sec
# epoch 9897, train loss 1.3394, train acc 0.558, test loss 1.4398, test acc 0.475, time 0.0 sec
# epoch 9898, train loss 1.3722, train acc 0.558, test loss 1.4624, test acc 0.475, time 0.0 sec
# epoch 9899, train loss 1.3160, train acc 0.558, test loss 1.5185, test acc 0.475, time 0.0 sec
# epoch 9900, train loss 1.3778, train acc 0.558, test loss 1.4528, test acc 0.475, time 0.0 sec
# epoch 9901, train loss 1.3256, train acc 0.558, test loss 1.4128, test acc 0.475, time 0.0 sec
# epoch 9902, train loss 1.3185, train acc 0.558, test loss 1.5307, test acc 0.475, time 0.0 sec
# epoch 9903, train loss 1.3189, train acc 0.558, test loss 1.4396, test acc 0.475, time 0.0 sec
# epoch 9904, train loss 1.2824, train acc 0.558, test loss 1.4043, test acc 0.475, time 0.0 sec
# epoch 9905, train loss 1.2688, train acc 0.558, test loss 1.4467, test acc 0.475, time 0.0 sec
# epoch 9906, train loss 1.2694, train acc 0.558, test loss 1.4154, test acc 0.475, time 0.0 sec
# epoch 9907, train loss 1.2706, train acc 0.558, test loss 1.4236, test acc 0.475, time 0.0 sec
# epoch 9908, train loss 1.2704, train acc 0.558, test loss 6.3411, test acc 0.508, time 0.0 sec
# epoch 9909, train loss 1.9619, train acc 0.562, test loss 1.4498, test acc 0.475, time 0.0 sec
# epoch 9910, train loss 1.3316, train acc 0.558, test loss 1.4335, test acc 0.475, time 0.0 sec
# epoch 9911, train loss 1.2947, train acc 0.558, test loss 1.4641, test acc 0.475, time 0.0 sec
# epoch 9912, train loss 1.2862, train acc 0.558, test loss 1.4234, test acc 0.475, time 0.0 sec
# epoch 9913, train loss 1.3073, train acc 0.558, test loss 1.4605, test acc 0.475, time 0.0 sec
# epoch 9914, train loss 1.2791, train acc 0.558, test loss 1.3969, test acc 0.475, time 0.0 sec
# epoch 9915, train loss 1.2696, train acc 0.558, test loss 1.4374, test acc 0.475, time 0.0 sec
# epoch 9916, train loss 1.2896, train acc 0.558, test loss 1.4389, test acc 0.475, time 0.0 sec
# epoch 9917, train loss 1.2877, train acc 0.558, test loss 1.4062, test acc 0.475, time 0.0 sec
# epoch 9918, train loss 1.2693, train acc 0.558, test loss 1.4834, test acc 0.475, time 0.0 sec
# epoch 9919, train loss 1.2962, train acc 0.558, test loss 1.4162, test acc 0.475, time 0.0 sec
# epoch 9920, train loss 1.2769, train acc 0.558, test loss 1.4989, test acc 0.475, time 0.0 sec
# epoch 9921, train loss 1.2939, train acc 0.558, test loss 1.6103, test acc 0.475, time 0.0 sec
# epoch 9922, train loss 1.3048, train acc 0.558, test loss 1.4273, test acc 0.475, time 0.0 sec
# epoch 9923, train loss 1.2829, train acc 0.558, test loss 1.4328, test acc 0.475, time 0.0 sec
# epoch 9924, train loss 1.2969, train acc 0.558, test loss 1.3976, test acc 0.475, time 0.0 sec
# epoch 9925, train loss 1.2876, train acc 0.558, test loss 1.4408, test acc 0.475, time 0.0 sec
# epoch 9926, train loss 1.3008, train acc 0.558, test loss 1.4554, test acc 0.475, time 0.0 sec
# epoch 9927, train loss 1.3026, train acc 0.558, test loss 1.4394, test acc 0.475, time 0.0 sec
# epoch 9928, train loss 263.6287, train acc 0.434, test loss 1.9808, test acc 0.475, time 0.0 sec
# epoch 9929, train loss 760.2559, train acc 0.500, test loss 3.0236, test acc 0.475, time 0.0 sec
# epoch 9930, train loss 2.6139, train acc 0.558, test loss 3.5969, test acc 0.475, time 0.0 sec
# epoch 9931, train loss 2.6148, train acc 0.558, test loss 3.0697, test acc 0.475, time 0.0 sec
# epoch 9932, train loss 2.2497, train acc 0.434, test loss 2.8779, test acc 0.475, time 0.0 sec
# epoch 9933, train loss 2.1094, train acc 0.558, test loss 2.6188, test acc 0.475, time 0.0 sec
# epoch 9934, train loss 1.9250, train acc 0.558, test loss 2.0558, test acc 0.475, time 0.0 sec
# epoch 9935, train loss 1.5738, train acc 0.450, test loss 1.7264, test acc 0.475, time 0.0 sec
# epoch 9936, train loss 1.3506, train acc 0.558, test loss 1.6322, test acc 0.475, time 0.0 sec
# epoch 9937, train loss 1.4607, train acc 0.558, test loss 1.4713, test acc 0.475, time 0.0 sec
# epoch 9938, train loss 1.4188, train acc 0.558, test loss 1.5922, test acc 0.475, time 0.0 sec
# epoch 9939, train loss 1.3474, train acc 0.558, test loss 1.4927, test acc 0.475, time 0.0 sec
# epoch 9940, train loss 1.4647, train acc 0.554, test loss 1.4229, test acc 0.475, time 0.0 sec
# epoch 9941, train loss 1.3322, train acc 0.558, test loss 1.4344, test acc 0.475, time 0.0 sec
# epoch 9942, train loss 1.2556, train acc 0.558, test loss 1.4505, test acc 0.475, time 0.0 sec
# epoch 9943, train loss 1.3230, train acc 0.558, test loss 1.4187, test acc 0.475, time 0.0 sec
# epoch 9944, train loss 1.2727, train acc 0.558, test loss 1.4099, test acc 0.475, time 0.0 sec
# epoch 9945, train loss 1.2926, train acc 0.558, test loss 1.4022, test acc 0.475, time 0.0 sec
# epoch 9946, train loss 1.2822, train acc 0.558, test loss 1.4282, test acc 0.475, time 0.0 sec
# epoch 9947, train loss 1.2797, train acc 0.558, test loss 1.4119, test acc 0.475, time 0.0 sec
# epoch 9948, train loss 1.3052, train acc 0.558, test loss 1.5068, test acc 0.475, time 0.0 sec
# epoch 9949, train loss 1.3119, train acc 0.558, test loss 1313.0481, test acc 0.475, time 0.0 sec
# epoch 9950, train loss 779.8401, train acc 0.479, test loss 1.5069, test acc 0.475, time 0.0 sec
# epoch 9951, train loss 1.3446, train acc 0.558, test loss 1.4226, test acc 0.475, time 0.0 sec
# epoch 9952, train loss 1.2948, train acc 0.558, test loss 1.4765, test acc 0.475, time 0.0 sec
# epoch 9953, train loss 1.3238, train acc 0.558, test loss 1.4845, test acc 0.475, time 0.0 sec
# epoch 9954, train loss 1.3571, train acc 0.558, test loss 1.3973, test acc 0.475, time 0.0 sec
# epoch 9955, train loss 1.3870, train acc 0.558, test loss 1.5622, test acc 0.475, time 0.0 sec
# epoch 9956, train loss 1.2871, train acc 0.558, test loss 1.4354, test acc 0.475, time 0.0 sec
# epoch 9957, train loss 1.3137, train acc 0.558, test loss 1.5337, test acc 0.475, time 0.0 sec
# epoch 9958, train loss 1.3893, train acc 0.558, test loss 1.4750, test acc 0.475, time 0.0 sec
# epoch 9959, train loss 1.2948, train acc 0.558, test loss 1.5037, test acc 0.475, time 0.0 sec
# epoch 9960, train loss 1.2936, train acc 0.558, test loss 1.4709, test acc 0.475, time 0.0 sec
# epoch 9961, train loss 1.8257, train acc 0.558, test loss 1.4807, test acc 0.475, time 0.0 sec
# epoch 9962, train loss 1.2700, train acc 0.558, test loss 1.3920, test acc 0.475, time 0.0 sec
# epoch 9963, train loss 1.2695, train acc 0.558, test loss 1.4948, test acc 0.475, time 0.0 sec
# epoch 9964, train loss 1.2829, train acc 0.558, test loss 1.4005, test acc 0.475, time 0.0 sec
# epoch 9965, train loss 1.3133, train acc 0.558, test loss 1.4357, test acc 0.475, time 0.0 sec
# epoch 9966, train loss 1.3224, train acc 0.558, test loss 1.4544, test acc 0.475, time 0.0 sec
# epoch 9967, train loss 1.3425, train acc 0.558, test loss 1.4539, test acc 0.475, time 0.0 sec
# epoch 9968, train loss 1.3085, train acc 0.558, test loss 1.5006, test acc 0.475, time 0.0 sec
# epoch 9969, train loss 1.3038, train acc 0.558, test loss 1.5129, test acc 0.475, time 0.0 sec
# epoch 9970, train loss 1.3142, train acc 0.558, test loss 1.4064, test acc 0.475, time 0.0 sec
# epoch 9971, train loss 1.3288, train acc 0.558, test loss 1.5032, test acc 0.475, time 0.0 sec
# epoch 9972, train loss 1.2914, train acc 0.558, test loss 1.4064, test acc 0.475, time 0.0 sec
# epoch 9973, train loss 1.2771, train acc 0.558, test loss 1.4852, test acc 0.475, time 0.0 sec
# epoch 9974, train loss 1.2896, train acc 0.558, test loss 1.3894, test acc 0.475, time 0.0 sec
# epoch 9975, train loss 1.2883, train acc 0.558, test loss 1.4404, test acc 0.475, time 0.0 sec
# epoch 9976, train loss 1.2920, train acc 0.558, test loss 1.4015, test acc 0.475, time 0.0 sec
# epoch 9977, train loss 1.3224, train acc 0.558, test loss 1.4452, test acc 0.475, time 0.0 sec
# epoch 9978, train loss 1.2626, train acc 0.558, test loss 1.4401, test acc 0.475, time 0.0 sec
# epoch 9979, train loss 1.3080, train acc 0.558, test loss 1.4361, test acc 0.475, time 0.0 sec
# epoch 9980, train loss 1.2956, train acc 0.558, test loss 1.4125, test acc 0.475, time 0.0 sec
# epoch 9981, train loss 1.2687, train acc 0.558, test loss 1.4119, test acc 0.475, time 0.0 sec
# epoch 9982, train loss 2.5524, train acc 0.545, test loss 1.4322, test acc 0.475, time 0.0 sec
# epoch 9983, train loss 1.2809, train acc 0.558, test loss 1.4183, test acc 0.475, time 0.0 sec
# epoch 9984, train loss 1.2670, train acc 0.558, test loss 1.3909, test acc 0.475, time 0.0 sec
# epoch 9985, train loss 60.8944, train acc 0.558, test loss 1.4202, test acc 0.475, time 0.0 sec
# epoch 9986, train loss 1.2880, train acc 0.558, test loss 1.4919, test acc 0.475, time 0.0 sec
# epoch 9987, train loss 1.2770, train acc 0.558, test loss 1.4083, test acc 0.475, time 0.0 sec
# epoch 9988, train loss 1.2677, train acc 0.558, test loss 1.5053, test acc 0.475, time 0.0 sec
# epoch 9989, train loss 1.3136, train acc 0.558, test loss 1.3948, test acc 0.475, time 0.0 sec
# epoch 9990, train loss 1.2769, train acc 0.558, test loss 1.5041, test acc 0.475, time 0.0 sec
# epoch 9991, train loss 1.3034, train acc 0.558, test loss 1.4017, test acc 0.475, time 0.0 sec
# epoch 9992, train loss 1.3028, train acc 0.558, test loss 1.5006, test acc 0.475, time 0.0 sec
# epoch 9993, train loss 1.3144, train acc 0.558, test loss 1.4611, test acc 0.475, time 0.0 sec
# epoch 9994, train loss 1.2815, train acc 0.558, test loss 1.5615, test acc 0.475, time 0.0 sec
# epoch 9995, train loss 1.4666, train acc 0.558, test loss 1.3887, test acc 0.475, time 0.0 sec
# epoch 9996, train loss 1.3381, train acc 0.558, test loss 1.5002, test acc 0.475, time 0.0 sec
# epoch 9997, train loss 1.2900, train acc 0.558, test loss 1.4182, test acc 0.475, time 0.0 sec
# epoch 9998, train loss 1.2799, train acc 0.558, test loss 1.4486, test acc 0.475, time 0.0 sec
# epoch 9999, train loss 6.3353, train acc 0.554, test loss 1.4200, test acc 0.475, time 0.0 sec
# epoch 10000, train loss 1.3325, train acc 0.558, test loss 1.5198, test acc 0.475, time 0.0 sec

# %% [markdown]
# # Problema 2
#
# Neste problema, você receberá 90 *features* extraídas de diversas músicas (datadas de 1922 até 2011) e deve predizer o ano de cada música. Mais sobre esse dataset aqui: https://archive.ics.uci.edu/ml/datasets/YearPredictionMSD

# %%
# download do dataset
# !wget http://archive.ics.uci.edu/ml/machine-learning-databases/00203/YearPredictionMSD.txt.zip
# !unzip YearPredictionMSD.txt.zip
data = np.genfromtxt('YearPredictionMSD.txt', delimiter=',', dtype=np.float32)

print(data[0, :])
X, y = data[:, 1:], data[:, 0]
train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.33, random_state=42)

batch_size = 100
train_iter = load_array(train_features, train_labels, batch_size)
test_iter = load_array(test_features, test_labels, batch_size, False)
# Out:
# --2025-05-20 03:25:36--  http://archive.ics.uci.edu/ml/machine-learning-databases/00203/YearPredictionMSD.txt.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘YearPredictionMSD.txt.zip’
#
# YearPredictionMSD.t     [             <=>    ] 201.24M  46.3MB/s    in 4.7s
#
# 2025-05-20 03:25:41 (42.8 MB/s) - ‘YearPredictionMSD.txt.zip’ saved [211011981]
#
# Archive:  YearPredictionMSD.txt.zip
#   inflating: YearPredictionMSD.txt
# [ 2.0010000e+03  4.9943569e+01  2.1471140e+01  7.3077499e+01
#   8.7486095e+00 -1.7406281e+01 -1.3099050e+01 -2.5012020e+01
#  -1.2232570e+01  7.8308902e+00 -2.4678299e+00  3.3213601e+00
#  -2.3152101e+00  1.0205560e+01  6.1110913e+02  9.5108960e+02
#   6.9811426e+02  4.0898486e+02  3.8370911e+02  3.2651511e+02
#   2.3811327e+02  2.5142413e+02  1.8717351e+02  1.0042652e+02
#   1.7919498e+02 -8.4155798e+00 -3.1787039e+02  9.5862663e+01
#   4.8102589e+01 -9.5663033e+01 -1.8062149e+01  1.9698400e+00
#   3.4424381e+01  1.1726700e+01  1.3679000e+00  7.7944398e+00
#  -3.6994001e-01 -1.3367851e+02 -8.3261650e+01 -3.7297649e+01
#   7.3046669e+01 -3.7366840e+01 -3.1385300e+00 -2.4215309e+01
#  -1.3230660e+01  1.5938090e+01 -1.8604780e+01  8.2154793e+01
#   2.4057980e+02 -1.0294070e+01  3.1584311e+01 -2.5381870e+01
#  -3.9077201e+00  1.3292580e+01  4.1550598e+01 -7.2627201e+00
#  -2.1008631e+01  1.0550848e+02  6.4298561e+01  2.6084810e+01
#  -4.4591099e+01 -8.3065701e+00  7.9370599e+00 -1.0736600e+01
#  -9.5447662e+01 -8.2033073e+01 -3.5591942e+01  4.6952500e+00
#   7.0956261e+01  2.8091391e+01  6.0201502e+00 -3.7137669e+01
#  -4.1124500e+01 -8.4081602e+00  7.1987700e+00 -8.6017599e+00
#  -5.9085698e+00 -1.2324370e+01  1.4687340e+01 -5.4321251e+01
#   4.0147861e+01  1.3016200e+01 -5.4405479e+01  5.8993671e+01
#   1.5373440e+01  1.1114399e+00 -2.3087931e+01  6.8407951e+01
#  -1.8222300e+00 -2.7463480e+01  2.2632699e+00]

# %%
# Rede neural para regressão com Dropout
net = nn.Sequential(
    nn.Linear(90, 228),
    nn.ReLU(),
    nn.Dropout(p=0.5),  # Dropout após 1ª ReLU
    nn.Linear(228, 228),
    nn.ReLU(),
    nn.Dropout(p=0.5),  # Dropout após 2ª ReLU
    nn.Linear(228, 1)  # Regressão → saída contínua
)

net.apply(weights_init)
net.to(device)

# Otimizador e função de perda para regressão
trainer = optim.Adam(net.parameters(), lr=0.003, weight_decay=0.001)
loss = nn.MSELoss()
num_epochs = 100

# Treinamento
train_validate(net, train_iter, test_iter, trainer, loss, num_epochs, type='regression')
# Out:
# training on cuda
# epoch 1, train loss 154764.5649, test loss 30414.0153, time 10.8 sec
# epoch 2, train loss 22528.4801, test loss 20160.3292, time 10.4 sec
# epoch 3, train loss 19600.0871, test loss 21294.4879, time 10.5 sec
# epoch 4, train loss 17772.3892, test loss 14325.8448, time 10.5 sec
# epoch 5, train loss 16178.5400, test loss 13664.4785, time 10.3 sec
# epoch 6, train loss 15071.8406, test loss 17698.7889, time 10.3 sec
# epoch 7, train loss 14329.2685, test loss 14439.0206, time 10.3 sec
# epoch 8, train loss 13911.6965, test loss 13433.9377, time 10.4 sec
# epoch 9, train loss 13471.7830, test loss 12565.4556, time 10.5 sec
# epoch 10, train loss 12779.9718, test loss 12072.8242, time 10.3 sec
# epoch 11, train loss 12714.8105, test loss 16563.5591, time 10.4 sec
# epoch 12, train loss 12107.9808, test loss 14030.3034, time 10.3 sec
# epoch 13, train loss 11909.1740, test loss 11162.9230, time 10.3 sec
# epoch 14, train loss 11507.9555, test loss 11350.6620, time 10.3 sec
# epoch 15, train loss 11200.5120, test loss 11966.4832, time 10.4 sec
# epoch 16, train loss 11029.6488, test loss 10352.9359, time 10.3 sec
# epoch 17, train loss 10943.3622, test loss 10203.2757, time 10.2 sec
# epoch 18, train loss 10538.7076, test loss 9728.6449, time 10.2 sec
# epoch 19, train loss 10456.3489, test loss 10585.7872, time 10.3 sec
# epoch 20, train loss 10178.2769, test loss 9616.0482, time 10.3 sec
# epoch 21, train loss 9977.5611, test loss 9470.9865, time 10.3 sec
# epoch 22, train loss 9970.8157, test loss 10590.5362, time 10.3 sec
# epoch 23, train loss 9646.6008, test loss 9291.8419, time 10.3 sec
# epoch 24, train loss 9476.6807, test loss 8962.2687, time 10.4 sec
# epoch 25, train loss 9319.1252, test loss 9028.4280, time 10.6 sec
# epoch 26, train loss 9235.5568, test loss 8712.2140, time 10.3 sec
# epoch 27, train loss 8987.8710, test loss 10020.1869, time 10.4 sec
# epoch 28, train loss 8857.3013, test loss 8546.4227, time 10.5 sec
# epoch 29, train loss 8665.1433, test loss 9088.4674, time 10.5 sec
# epoch 30, train loss 8458.7150, test loss 8236.5179, time 10.4 sec
# epoch 31, train loss 8428.1880, test loss 7773.6343, time 10.5 sec
# epoch 32, train loss 8196.2708, test loss 7603.0417, time 10.4 sec
# epoch 33, train loss 7935.1076, test loss 7700.0741, time 10.5 sec
# epoch 34, train loss 8040.1724, test loss 8753.8848, time 10.2 sec
# epoch 35, train loss 7602.6829, test loss 7354.2158, time 10.3 sec
# epoch 36, train loss 7235.8946, test loss 6947.9271, time 10.3 sec
# epoch 37, train loss 6638.0664, test loss 7448.3163, time 10.3 sec
# epoch 38, train loss 5693.3384, test loss 5127.4891, time 10.3 sec
# epoch 39, train loss 4535.1962, test loss 3729.5076, time 10.3 sec
# epoch 40, train loss 2980.8304, test loss 2469.9553, time 10.3 sec
# epoch 41, train loss 1612.4658, test loss 894.4625, time 10.3 sec
# epoch 42, train loss 585.1765, test loss 298.1675, time 10.3 sec
# epoch 43, train loss 419.5304, test loss 233.6058, time 10.2 sec
# epoch 44, train loss 288.5859, test loss 146.0339, time 10.2 sec
# epoch 45, train loss 238.4906, test loss 145.2347, time 10.4 sec
# epoch 46, train loss 161.2629, test loss 131.2881, time 10.4 sec
# epoch 47, train loss 348.3174, test loss 125.7729, time 10.4 sec
# epoch 48, train loss 234.8472, test loss 125.5663, time 10.4 sec
# epoch 49, train loss 163.6958, test loss 126.1945, time 10.6 sec
# epoch 50, train loss 174.6872, test loss 124.6860, time 10.4 sec
# epoch 51, train loss 222.0915, test loss 125.1484, time 10.4 sec
# epoch 52, train loss 135.7779, test loss 161.5459, time 10.3 sec
# epoch 53, train loss 184.8191, test loss 128.9208, time 10.3 sec
# epoch 54, train loss 195.1621, test loss 124.7397, time 10.5 sec
# epoch 55, train loss 181.5259, test loss 123.5334, time 10.4 sec
# epoch 56, train loss 156.2734, test loss 126.3335, time 10.5 sec
# epoch 57, train loss 161.2294, test loss 122.0694, time 10.4 sec
# epoch 58, train loss 130.5046, test loss 125.8575, time 10.3 sec
# epoch 59, train loss 216.3136, test loss 149.0413, time 10.3 sec
# epoch 60, train loss 147.2662, test loss 155.2437, time 10.5 sec
# epoch 61, train loss 140.9996, test loss 139.8415, time 10.2 sec
# epoch 62, train loss 171.6679, test loss 133.8688, time 10.3 sec
# epoch 63, train loss 316.9584, test loss 123.7541, time 10.3 sec
# epoch 64, train loss 123.9639, test loss 141.5565, time 10.3 sec
# epoch 65, train loss 139.2110, test loss 125.4942, time 10.3 sec
# epoch 66, train loss 145.2455, test loss 139.0336, time 10.3 sec
# epoch 67, train loss 132.0280, test loss 124.1458, time 10.4 sec
# epoch 68, train loss 150.5319, test loss 120.9848, time 10.3 sec
# epoch 69, train loss 131.0101, test loss 155.4504, time 10.3 sec
# epoch 70, train loss 193.0309, test loss 132.3128, time 10.3 sec
# epoch 71, train loss 164.3240, test loss 125.9125, time 10.4 sec
# epoch 72, train loss 143.3522, test loss 129.0417, time 10.6 sec
# epoch 73, train loss 174.5352, test loss 125.8310, time 10.5 sec
# epoch 74, train loss 156.7199, test loss 121.8357, time 10.4 sec
# epoch 75, train loss 150.9357, test loss 125.6340, time 10.3 sec
# epoch 76, train loss 189.6617, test loss 126.8628, time 10.4 sec
# epoch 77, train loss 148.6503, test loss 124.9845, time 10.4 sec
# epoch 78, train loss 169.1056, test loss 122.8781, time 10.3 sec
# epoch 79, train loss 136.0716, test loss 124.0069, time 10.3 sec
# epoch 80, train loss 130.2029, test loss 149.9289, time 10.3 sec
# epoch 81, train loss 130.6100, test loss 147.4545, time 10.3 sec
# epoch 82, train loss 150.9012, test loss 171.2959, time 10.4 sec
# epoch 83, train loss 218.3130, test loss 156.8574, time 10.4 sec
# epoch 84, train loss 148.6515, test loss 135.4990, time 10.4 sec
# epoch 85, train loss 128.0836, test loss 126.1488, time 10.3 sec
# epoch 86, train loss 125.7797, test loss 121.0510, time 10.3 sec
# epoch 87, train loss 141.9345, test loss 123.9495, time 10.3 sec
# epoch 88, train loss 133.3879, test loss 127.3493, time 10.5 sec
# epoch 89, train loss 143.9369, test loss 129.0556, time 10.5 sec
# epoch 90, train loss 188.1429, test loss 127.0771, time 10.4 sec
# epoch 91, train loss 160.9057, test loss 127.6842, time 10.3 sec
# epoch 92, train loss 150.8358, test loss 124.6436, time 10.4 sec
# epoch 93, train loss 149.8765, test loss 122.5087, time 10.4 sec
# epoch 94, train loss 140.7619, test loss 121.7666, time 10.5 sec
# epoch 95, train loss 150.9424, test loss 121.3962, time 10.5 sec
# epoch 96, train loss 134.0080, test loss 120.6596, time 10.3 sec
# epoch 97, train loss 172.8066, test loss 766.9660, time 10.4 sec
# epoch 98, train loss 154.7973, test loss 120.8615, time 10.3 sec
# epoch 99, train loss 133.3992, test loss 120.1839, time 10.5 sec
# epoch 100, train loss 190.8679, test loss 120.0521, time 10.4 sec

# %%
# mostra o resultado predito para as 5 primeiras instâncias de teste
y = net(torch.Tensor(test_features[0:5, :]).to(device))
print(y, test_labels[0:5])
# Out:
# tensor([[1998.9092],
#         [1998.9092],
#         [1998.9092],
#         [1998.9092],
#         [1998.9092]], device='cuda:0', grad_fn=<AddmmBackward0>) [2008. 2001. 2006. 2008. 1998.]

# %% [markdown]
# # Problema 3
#
# Neste problema, você receberá várias *features* (como altura média, inclinação, etc) descrevendo uma região e o modelo deve predizer qual o tipo da região (floresta, montanha, etc). Mais informações sobre esse dataset aqui: https://archive.ics.uci.edu/ml/datasets/covertype

# %%
# !wget http://archive.ics.uci.edu/ml/machine-learning-databases/covtype/covtype.data.gz
# !gzip covtype.data.gz
data = np.genfromtxt('covtype.data', delimiter=',', dtype=np.float32)

print(data.shape, data[0, :])
X, y = data[:, :-1], data[:, -1]
print(X.shape, X[0, :])
print(y.shape, y[0])
train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.33, random_state=42)
train_labels = train_labels - 1
test_labels = test_labels - 1

batch_size = 100
train_iter = load_array(train_features, train_labels, batch_size)
test_iter = load_array(test_features, test_labels, batch_size, False)
# Out:
# --2025-05-20 03:56:49--  http://archive.ics.uci.edu/ml/machine-learning-databases/covtype/covtype.data.gz
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘covtype.data.gz’
#
# covtype.data.gz         [   <=>              ]  10.72M  17.2MB/s    in 0.6s
#
# 2025-05-20 03:56:49 (17.2 MB/s) - ‘covtype.data.gz’ saved [11240707]
#
# gzip: covtype.data.gz already has .gz suffix -- unchanged
# (581012, 55) [2.596e+03 5.100e+01 3.000e+00 2.580e+02 0.000e+00 5.100e+02 2.210e+02
#  2.320e+02 1.480e+02 6.279e+03 1.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  1.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 5.000e+00]
# (581012, 54) [2.596e+03 5.100e+01 3.000e+00 2.580e+02 0.000e+00 5.100e+02 2.210e+02
#  2.320e+02 1.480e+02 6.279e+03 1.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  1.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00
#  0.000e+00 0.000e+00 0.000e+00 0.000e+00 0.000e+00]
# (581012,) 5.0

# %%
# IMPLEMENTE AQUI

net = nn.Sequential(
    nn.Linear(54, 128),
    nn.ReLU(),
    nn.Dropout(p=0.4),
    nn.Linear(128, 64),
    nn.ReLU(),
    nn.Dropout(p=0.3),
    nn.Linear(64, 32),
    nn.ReLU(),
    nn.Linear(32, 7)  # 7 classes
)

net.apply(weights_init)
net.to(device)

trainer = optim.Adam(net.parameters(), lr=0.001, weight_decay=1e-4)
loss = nn.CrossEntropyLoss()
num_epochs = 50

train_validate(net, train_iter, test_iter, trainer, loss, num_epochs, type='classification')
# Out:
# training on cuda
# epoch 1, train loss 0.9088, train acc 0.608, test loss 0.7814, test acc 0.684, time 12.5 sec
# epoch 2, train loss 0.6734, train acc 0.711, test loss 0.6114, test acc 0.737, time 12.0 sec
# epoch 3, train loss 0.6137, train acc 0.733, test loss 0.5966, test acc 0.740, time 12.0 sec
# epoch 4, train loss 0.5815, train acc 0.746, test loss 0.5732, test acc 0.747, time 12.0 sec
# epoch 5, train loss 0.5621, train acc 0.754, test loss 0.5706, test acc 0.748, time 12.0 sec
# epoch 6, train loss 0.5457, train acc 0.762, test loss 0.5322, test acc 0.767, time 12.1 sec
# epoch 7, train loss 0.5337, train acc 0.768, test loss 0.5310, test acc 0.767, time 12.3 sec
# epoch 8, train loss 0.5214, train acc 0.774, test loss 0.5700, test acc 0.760, time 12.1 sec
# epoch 9, train loss 0.5153, train acc 0.777, test loss 0.5050, test acc 0.782, time 12.0 sec
# epoch 10, train loss 0.5073, train acc 0.781, test loss 0.5080, test acc 0.782, time 12.0 sec
# epoch 11, train loss 0.4983, train acc 0.785, test loss 0.5135, test acc 0.780, time 12.1 sec
# epoch 12, train loss 0.4940, train acc 0.788, test loss 0.4857, test acc 0.790, time 12.1 sec
# epoch 13, train loss 0.4881, train acc 0.790, test loss 0.4712, test acc 0.798, time 12.2 sec
# epoch 14, train loss 0.4826, train acc 0.792, test loss 0.4781, test acc 0.794, time 12.2 sec
# epoch 15, train loss 0.4779, train acc 0.795, test loss 0.4707, test acc 0.799, time 12.2 sec
# epoch 16, train loss 0.4754, train acc 0.796, test loss 0.4745, test acc 0.796, time 12.2 sec
# epoch 17, train loss 0.4704, train acc 0.798, test loss 0.4891, test acc 0.792, time 12.1 sec
# epoch 18, train loss 0.4689, train acc 0.798, test loss 0.4717, test acc 0.798, time 12.1 sec
# epoch 19, train loss 0.4655, train acc 0.800, test loss 0.4621, test acc 0.801, time 12.0 sec
# epoch 20, train loss 0.4634, train acc 0.801, test loss 0.4800, test acc 0.796, time 12.1 sec
# epoch 21, train loss 0.4630, train acc 0.802, test loss 0.4800, test acc 0.791, time 12.2 sec
# epoch 22, train loss 0.4602, train acc 0.802, test loss 0.4464, test acc 0.811, time 12.2 sec
# epoch 23, train loss 0.4572, train acc 0.804, test loss 0.4458, test acc 0.810, time 12.2 sec
# epoch 24, train loss 0.4568, train acc 0.804, test loss 0.4665, test acc 0.799, time 12.2 sec
# epoch 25, train loss 0.4547, train acc 0.805, test loss 0.4734, test acc 0.799, time 12.0 sec
# epoch 26, train loss 0.4534, train acc 0.805, test loss 0.4583, test acc 0.804, time 12.0 sec
# epoch 27, train loss 0.4511, train acc 0.807, test loss 0.4461, test acc 0.809, time 12.0 sec
# epoch 28, train loss 0.4479, train acc 0.809, test loss 0.4559, test acc 0.803, time 12.0 sec
# epoch 29, train loss 0.4460, train acc 0.809, test loss 0.4385, test acc 0.813, time 12.2 sec
# epoch 30, train loss 0.4458, train acc 0.809, test loss 0.4508, test acc 0.806, time 12.2 sec
# epoch 31, train loss 0.4451, train acc 0.810, test loss 0.4706, test acc 0.798, time 12.0 sec
# epoch 32, train loss 0.4421, train acc 0.811, test loss 0.4574, test acc 0.806, time 12.0 sec
# epoch 33, train loss 0.4407, train acc 0.812, test loss 0.4569, test acc 0.807, time 12.0 sec
# epoch 34, train loss 0.4411, train acc 0.811, test loss 0.4350, test acc 0.812, time 12.2 sec
# epoch 35, train loss 0.4392, train acc 0.812, test loss 0.4366, test acc 0.815, time 12.1 sec
# epoch 36, train loss 0.4387, train acc 0.813, test loss 0.4295, test acc 0.817, time 12.1 sec
# epoch 37, train loss 0.4360, train acc 0.814, test loss 0.4431, test acc 0.811, time 12.1 sec
# epoch 38, train loss 0.4342, train acc 0.814, test loss 0.4394, test acc 0.812, time 12.1 sec
# epoch 39, train loss 0.4354, train acc 0.814, test loss 0.4350, test acc 0.814, time 12.0 sec
# epoch 40, train loss 0.4334, train acc 0.815, test loss 0.4210, test acc 0.821, time 12.1 sec
# epoch 41, train loss 0.4316, train acc 0.816, test loss 0.4557, test acc 0.806, time 12.2 sec
# epoch 42, train loss 0.4336, train acc 0.815, test loss 0.4515, test acc 0.808, time 12.3 sec
# epoch 43, train loss 0.4323, train acc 0.816, test loss 0.4478, test acc 0.808, time 12.1 sec
# epoch 44, train loss 0.4304, train acc 0.817, test loss 0.4557, test acc 0.806, time 12.1 sec
# epoch 45, train loss 0.4302, train acc 0.817, test loss 0.4484, test acc 0.808, time 12.2 sec
# epoch 46, train loss 0.4289, train acc 0.817, test loss 0.4362, test acc 0.815, time 12.2 sec
# epoch 47, train loss 0.4295, train acc 0.817, test loss 0.4215, test acc 0.821, time 12.1 sec
# epoch 48, train loss 0.4269, train acc 0.819, test loss 0.4289, test acc 0.816, time 12.1 sec
# epoch 49, train loss 0.4268, train acc 0.818, test loss 0.4249, test acc 0.821, time 12.0 sec
# epoch 50, train loss 0.4256, train acc 0.819, test loss 0.4190, test acc 0.823, time 12.0 sec

# %%
acc, avg_loss = evaluate_accuracy(test_iter, net, loss)

# %%
print(f"acc = {acc}")
print(f"avg_loss = {avg_loss}")
# Out:
# acc = 0.8233385836627828
# avg_loss = 0.4189929822935675

# %% [markdown]
# # Problema 4
#
# Neste problema, você receberá 11 *features* extraídas de tipos de vinhos, e terá que predizer um *score* para cada vinho. Mais sobre esse dataset aqui: https://archive.ics.uci.edu/ml/datasets/Wine+Quality

# %%
# download do dataset
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv
data_red = np.genfromtxt('winequality-red.csv', delimiter=';', dtype=np.float32, skip_header=1)
data_white = np.genfromtxt('winequality-white.csv', delimiter=';', dtype=np.float32, skip_header=1)
data = np.concatenate((data_red, data_white), axis=0)
data = np.nan_to_num(data)

print(data[0, :])
X, y = data[:, :-1], data[:, -1]
print(X.shape, y.shape)
train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.33, random_state=42)

batch_size = 100
train_iter = load_array(train_features, train_labels, batch_size)
test_iter = load_array(test_features, test_labels, batch_size, False)
# Out:
# --2025-05-20 04:08:10--  https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘winequality-red.csv’
#
# winequality-red.csv     [ <=>                ]  82.23K  --.-KB/s    in 0.1s
#
# 2025-05-20 04:08:11 (575 KB/s) - ‘winequality-red.csv’ saved [84199]
#
# --2025-05-20 04:08:11--  https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘winequality-white.csv’
#
# winequality-white.c     [ <=>                ] 258.23K  1.33MB/s    in 0.2s
#
# 2025-05-20 04:08:12 (1.33 MB/s) - ‘winequality-white.csv’ saved [264426]
#
# [ 7.4     0.7     0.      1.9     0.076  11.     34.      0.9978  3.51
#   0.56    9.4     5.    ]
# (6497, 11) (6497,)

# %%
# IMPLEMENTE AQUI

net = nn.Sequential(
    nn.Linear(11, 64),
    nn.ReLU(),
    nn.Dropout(p=0.4),
    nn.Linear(64, 32),
    nn.ReLU(),
    nn.Linear(32, 1)  # saída contínua
)

net.apply(weights_init)
net.to(device)

# Otimizador e perda
trainer = optim.Adam(net.parameters(), lr=0.003, weight_decay=1e-4)
loss = nn.MSELoss()
num_epochs = 32

# Treinamento
train_validate(net, train_iter, test_iter, trainer, loss, num_epochs, type='regression')
# Out:
# training on cuda
# epoch 1, train loss 11.6568, test loss 3.8871, time 0.1 sec
# epoch 2, train loss 1.9504, test loss 0.8732, time 0.1 sec
# epoch 3, train loss 0.8921, test loss 0.8640, time 0.1 sec
# epoch 4, train loss 0.8879, test loss 0.8457, time 0.2 sec
# epoch 5, train loss 0.8882, test loss 0.8380, time 0.1 sec
# epoch 6, train loss 0.8824, test loss 0.8357, time 0.1 sec
# epoch 7, train loss 0.8817, test loss 0.8342, time 0.1 sec
# epoch 8, train loss 0.8600, test loss 0.8651, time 0.1 sec
# epoch 9, train loss 0.8916, test loss 0.8267, time 0.1 sec
# epoch 10, train loss 0.8587, test loss 0.9476, time 0.1 sec
# epoch 11, train loss 0.8875, test loss 0.8255, time 0.1 sec
# epoch 12, train loss 0.8538, test loss 0.8124, time 0.1 sec
# epoch 13, train loss 0.8617, test loss 0.8083, time 0.1 sec
# epoch 14, train loss 0.8595, test loss 0.8082, time 0.1 sec
# epoch 15, train loss 0.8378, test loss 0.8025, time 0.1 sec
# epoch 16, train loss 0.8550, test loss 0.8285, time 0.1 sec
# epoch 17, train loss 0.8642, test loss 0.8041, time 0.1 sec
# epoch 18, train loss 0.8465, test loss 0.8494, time 0.1 sec
# epoch 19, train loss 0.8552, test loss 0.7934, time 0.1 sec
# epoch 20, train loss 0.8345, test loss 0.7947, time 0.1 sec
# epoch 21, train loss 0.8435, test loss 0.8077, time 0.1 sec
# epoch 22, train loss 0.8467, test loss 0.7887, time 0.1 sec
# epoch 23, train loss 0.8294, test loss 0.8001, time 0.1 sec
# epoch 24, train loss 0.8514, test loss 0.7873, time 0.1 sec
# epoch 25, train loss 0.8311, test loss 0.7820, time 0.1 sec
# epoch 26, train loss 0.8297, test loss 0.8200, time 0.1 sec
# epoch 27, train loss 0.8380, test loss 0.8057, time 0.1 sec
# epoch 28, train loss 0.8189, test loss 0.7879, time 0.1 sec
# epoch 29, train loss 0.8297, test loss 0.8067, time 0.1 sec
# epoch 30, train loss 0.8335, test loss 0.7931, time 0.1 sec
# epoch 31, train loss 0.8216, test loss 0.7795, time 0.1 sec
# epoch 32, train loss 0.8316, test loss 0.8204, time 0.1 sec

# %%
# mostra o resultado predito para as 5 primeiras instâncias de teste
y = net(torch.Tensor(test_features[0:5, :]).to(device))
print(y, test_labels[0:5])
# Out:
# tensor([[5.8315],
#         [5.6309],
#         [5.7450],
#         [5.3989],
#         [5.5434]], device='cuda:0', grad_fn=<AddmmBackward0>) [8. 5. 7. 6. 6.]
